css?rq6f28" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/optimized/css__Jd5jGOK2GKkWJ39lq12bpzDKZcqQg7jBxXFi9MwHsU.2jiCIxMmrw5Ya85h0gXtVlX49sz_o7is8iR2k__UncU.css?rq6f28" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/optimized/css_J6dLcwxLPT2uFEuf2TVbXMPFtkZKGxtZV5vaIL-CqGU.Ws97Vi_zP65ttqmKsHvG9BUgtiwUzRIhC3c8y6u8HTk.css?rq6f28" media="all" rel="stylesheet"/>
#   <link href="/sites/default/files/css/optimized/css_Whjr_G34vQrSoJsSvC_zXgge2_ErDvYAZCgvEoaNNlQ.LbQvMij-9N86RGN5wKEw41OW71FIJxp1dKl0g3qc6Fg.css?rq6f28" media="all" rel="stylesheet"/>
#  </head>
#  <body class="path-centre-audition">
#   <a class="visually-hidden focusable skip-link" href="#main-content">
#    Aller au contenu principal
#   </a>
#   <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#    <div class="layout-container">
#     <header role="banner">
#      <div class="region region-header">
#       <div class="block block-system block-system-branding-block" id="block-vivason-site-branding">
#        <a class="site-logo" href="/" rel="home">
#         <img alt="Accueil" src="/themes/custom/vivason/logo.jpg"/>
#        </a>
#        <div class="site-name">
#         <a href="/" rel="home">
#          VivaSon
#         </a>
#        </div>
#       </div>
#       <div class="block block-vivason-common block-vivason-menu-principal" id="block-vivasonmenuprincipalblock">
#        <div>
#         <input class="button js-form-submit form-submit" name="op" type="submit" value="X"/>
#         <div class="groupe-2">
#          <span class="obflink accueil" data-o="Lw==">
#           Accueil
#          </span>
#          <div class="le-guide">
#           <a class="le-guide-parent" href="/appareil-auditif" title="Le guide">
#            Le guide
#           </a>
#           <div class="submenu-wrapper">
#            <div class="column-left">
#             <img alt="" src="/sites/default/files/2021-09/Image_menu_Le_Guide.jpg"/>
#            </div>
#            <div class="column-right">
#             <span class="title obflink" data-o="L2FwcGFyZWlsLWF1ZGl0aWY=">
#              <strong>
#               Le guide
#              </strong>
#              des appareils auditifs
#             </span>
#             <ul class="menu menu-level-0">
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2585" href="/appareil-auditif/prix" title="Les prix des appareils auditifs">
#                Les prix des appareils auditifs
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2741" href="/appareil-auditif/remboursement" title="Remboursement des appareils auditifs">
#                Remboursement des appareils auditifs
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2583" href="/appareil-auditif/types" title="Types d'appareils auditifs">
#                Types d'appareils auditifs
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2581" href="/appareil-auditif/choisir" title="Quel appareil auditif choisir">
#                Quel appareil auditif choisir
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2745" href="/appareil-auditif/fonctionnement">
#                Fonctionnement des appareils auditifs &amp; Intérêt
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/3286" href="/appareil-auditif/marques">
#                Quelle marque d'appareil auditif choisir ?
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/3420" href="/appareil-auditif/audioprothesiste">
#                Audioprothésiste
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="votre-audition">
#           <a class="votre-audition-parent" href="/votre-audition" title="Votre audition">
#            Votre audition
#           </a>
#           <div class="submenu-wrapper">
#            <div class="column-left">
#             <img alt="" src="/sites/default/files/2021-09/Image_menu_votre_audition.jpg"/>
#            </div>
#            <div class="column-right">
#             <span class="title">
#              <strong>
#               Votre
#              </strong>
#              audition
#             </span>
#             <ul class="menu menu-level-0">
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2582" href="/votre-audition/test-auditif" title="Test auditif">
#                Le bilan auditif
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/3297" href="/notre-test-auditif-en-ligne-gratuit">
#                Le test auditif en ligne
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2584" href="/votre-audition/perte-auditive" title="Perte auditive et surdité">
#                Perte auditive et surdité
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2580" href="/votre-audition/acouphene" title="Acouphènes et hyperacousie">
#                Acouphènes et hyperacousie
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2761" href="/votre-audition/maladies-auditives" title="Les pathologies de l'audition">
#                Les pathologies de l'audition
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/2770" href="/votre-audition/oreille" title="Fonctionnement de l'oreille">
#                Fonctionnement de l'oreille
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="nos-appareils">
#           <a class="appareils-auditifs-parent" href="/nos-appareils-auditifs">
#            Nos appareils auditifs
#           </a>
#           <div class="submenu-wrapper">
#            <div class="column-left">
#             <img alt="" src="/sites/default/files/2021-09/Image_menu_appareils_auditifs.jpg"/>
#            </div>
#            <div class="column-right">
#             <span class="title">
#              <strong>
#               Nos appareils
#              </strong>
#              auditifs
#             </span>
#             <a class="appareils-auditifs-parent" href="/nos-appareils-auditifs">
#              Voir tous les appareils auditifs
#             </a>
#             <div class="menu-wrapper-items">
#              <div class="menu-wrapper item-marques" data-uuid="d3b865a8-6aba-4b56-9a16-42aee1200bc7">
#               <span class="h3">
#                Marques
#               </span>
#               <ul class="menu menu-level-0">
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/signia-12" href="/nos-appareils-auditifs/signia" title="Signia by Siemens">
#                  Signia by Siemens
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/starkey-13" href="/nos-appareils-auditifs/starkey" title="Starkey">
#                  Starkey
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/resound-9" href="/nos-appareils-auditifs/resound" title="Resound">
#                  Resound
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/philips-7" href="/nos-appareils-auditifs/philips" title="Philips">
#                  Philips
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/beltone-3" href="/nos-appareils-auditifs/beltone" title="Beltone">
#                  Beltone
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/oticon-6" href="/nos-appareils-auditifs/oticon" title="Oticon">
#                  Oticon
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/phonak-8" href="/nos-appareils-auditifs/phonak" title="Phonak">
#                  Phonak
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/hansaton-5" href="/nos-appareils-auditifs/hansaton" title="Hansaton">
#                  Hansaton
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/widex-14" href="/nos-appareils-auditifs/widex" title="Widex">
#                  Widex
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/marque/unitron-15" href="/nos-appareils-auditifs/unitron" title="Unitron">
#                  Unitron
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#               </ul>
#              </div>
#              <div class="menu-wrapper item-prix" data-uuid="b2a495c1-0657-4480-90c0-2f692dffcd85">
#               <span class="h3">
#                Prix
#               </span>
#               <ul class="menu menu-level-0">
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/prix/economique" href="/nos-appareils-auditifs/classe-1" title="Classe 1 - 100% Santé">
#                  Classe 1 - 950€ (100% Remboursé)
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/prix/dynamique" href="/nos-appareils-auditifs/dynamique" title="Dynamique - 950€ à 1095€">
#                  Dynamique - 950€ à 1095€
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/prix/excellence" href="/nos-appareils-auditifs/excellence" title="Excellence - 1195€">
#                  Excellence - 1195€
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#               </ul>
#              </div>
#              <div class="menu-wrapper item-types" data-uuid="39fc85bf-7ba2-47ee-ac74-25210801ab74">
#               <span class="h3">
#                Types
#               </span>
#               <ul class="menu menu-level-0">
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/types/intra" href="/nos-appareils-auditifs/intra-auriculaire" title="Intra-auriculaires">
#                  Intra-auriculaires
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/types/micro" href="/nos-appareils-auditifs/micro-contour" title="Micro-contours">
#                  Micro-contours d'oreille RIC
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/types/contour" href="/nos-appareils-auditifs/contour-classique" title="Contours classiques">
#                  Contours d'oreille BTE
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#               </ul>
#              </div>
#              <div class="menu-wrapper item-options" data-uuid="bb1eab6e-28fb-4949-8c9b-293578310a7a">
#               <span class="h3">
#                Options
#               </span>
#               <ul class="menu menu-level-0">
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/options/rechargeable" href="/nos-appareils-auditifs/rechargeable" title="Rechargeable">
#                  Rechargeable
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/options/bluetooth_produit" href="/nos-appareils-auditifs/bluetooth" title="Bluetooth">
#                  Bluetooth
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#                <li class="menu-item">
#                 <a data-drupal-link-system-path="nos-appareils-auditifs/options/acouphene" href="/nos-appareils-auditifs/acouphenes" title="Acouphènes">
#                  Acouphènes
#                 </a>
#                 <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#                 </div>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="groupe-2">
#          <div class="qui-sommes-nous">
#           <span class="obflink qui-sommes-nous-parent" data-o="L3F1aS1zb21tZXMtbm91cy9ub3RyZS1oaXN0b2lyZQ==">
#            Qui sommes-nous ?
#           </span>
#           <div class="submenu-wrapper">
#            <div class="column-left">
#             <div>
#              <span class="qsn-baseline">
#               Entendre la vie en
#               <b>
#                rose
#               </b>
#              </span>
#              <p>
#               Bien entendre c’est rajeunir et vous proposons donc une approche enthousiaste de l’appareillage auditif. Confiez-nous votre audition pour Entendre la vie en rose
#              </p>
#             </div>
#             <img alt="" src="/sites/default/files/2021-09/menu_icon_6758.jpg"/>
#            </div>
#            <div class="column-right">
#             <ul class="menu menu-level-">
#              <li>
#               <span class="obflink" data-o="L3F1aS1zb21tZXMtbm91cy9ub3RyZS1oaXN0b2lyZQ==">
#                Notre histoire
#               </span>
#              </li>
#              <li>
#               <span class="obflink" data-o="L3F1aS1zb21tZXMtbm91cy9ub3RyZS1waGlsb3NvcGhpZQ==">
#                Notre philosophie
#               </span>
#              </li>
#              <li>
#               <span class="obflink" data-o="L3F1aS1zb21tZXMtbm91cy9wb3VycXVvaS12aXZhc29u">
#                Pourquoi vivason ?
#               </span>
#              </li>
#              <li class="menu-item">
#               <a data-drupal-link-system-path="node/96" href="/content/recrutement">
#                Nous rejoindre
#               </a>
#               <div class="menu_link_content menu-link-contentmain view-mode-default menu-dropdown menu-dropdown-0 menu-type-default">
#               </div>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="actualites">
#           <a class="actualites-parent" href="/actualites">
#            Actus
#           </a>
#           <div class="submenu-wrapper">
#            <div class="column-left">
#             <span class="title">
#              <strong>
#               À la une
#              </strong>
#              cette semaine
#             </span>
#             <article data-nid="3337" role="article">
#              <div>
#               <div class="title">
#                <a href="/actualites/starkey-evolv-ai-la-nouvelle-generation-dappareils-auditifs-du-leader-americain" hreflang="fr">
#                 Starkey Evolv AI : la nouvelle génération d'appareils auditifs du leader américain
#                </a>
#               </div>
#               <span class="field field--name-created field--type-created field--label-hidden">
#                13 avril 2022
#               </span>
#              </div>
#             </article>
#             <div class="field field--name-field-image-principale field--type-entity-reference field--label-hidden field__item">
#              <article class="media media--type-image media--view-mode-entete-contenus">
#               <div class="field field--name-field-media-image field--type-image field--label-visually_hidden" data-created-day="###CREATED_DATE###">
#                <div class="field__label visually-hidden">
#                 Image
#                </div>
#                <div class="field__item">
#                 <picture>
#                  <source media="all and (min-width: 1266px)" srcset="/sites/default/files/styles/entete_contenus/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.webp?h=6653b512&amp;itok=XDz6hK5Z 1x" type="image/webp"/>
#                  <source media="all and (min-width: 961px) and (max-width: 1265px)" srcset="/sites/default/files/styles/entete_contenus/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.webp?h=6653b512&amp;itok=XDz6hK5Z 1x" type="image/webp"/>
#                  <source media="all and (min-width: 376px) and (max-width: 960px)" srcset="/sites/default/files/styles/entete_contenus_mobile/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.webp?h=6653b512&amp;itok=ASVhHML9 1x" type="image/webp"/>
#                  <source media="all and (min-width: 341px) and (max-width: 375px)" srcset="/sites/default/files/styles/entete_contenus_mobile/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.webp?h=6653b512&amp;itok=ASVhHML9 1x" type="image/webp"/>
#                  <source media="all and (max-width: 340px)" srcset="/sites/default/files/styles/entete_contenus_mobile/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.webp?h=6653b512&amp;itok=ASVhHML9 1x" type="image/webp"/>
#                  <source media="all and (min-width: 1266px)" srcset="/sites/default/files/styles/entete_contenus/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.jpg?h=6653b512&amp;itok=XDz6hK5Z 1x" type="image/jpeg"/>
#                  <source media="all and (min-width: 961px) and (max-width: 1265px)" srcset="/sites/default/files/styles/entete_contenus/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.jpg?h=6653b512&amp;itok=XDz6hK5Z 1x" type="image/jpeg"/>
#                  <source media="all and (min-width: 376px) and (max-width: 960px)" srcset="/sites/default/files/styles/entete_contenus_mobile/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.jpg?h=6653b512&amp;itok=ASVhHML9 1x" type="image/jpeg"/>
#                  <source media="all and (min-width: 341px) and (max-width: 375px)" srcset="/sites/default/files/styles/entete_contenus_mobile/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.jpg?h=6653b512&amp;itok=ASVhHML9 1x" type="image/jpeg"/>
#                  <source media="all and (max-width: 340px)" srcset="/sites/default/files/styles/entete_contenus_mobile/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.jpg?h=6653b512&amp;itok=ASVhHML9 1x" type="image/jpeg"/>
#                  <img alt="Starkey Evolv AI : la nouvelle génération d'appareils auditifs du leader américainStarkey Evolv AI : la nouvelle génération d'appareils auditifs du leader américain" src="/sites/default/files/styles/entete_contenus_mobile/public/medias/image/appareils_auditifs_starkey_Evolv_Ai.jpg?h=6653b512&amp;itok=ASVhHML9"/>
#                 </picture>
#                </div>
#               </div>
#              </article>
#             </div>
#            </div>
#            <div class="column-right">
#             <span class="title">
#              <a href="/actualites">
#               <strong>
#                Toute
#               </strong>
#               l'actualité
#              </a>
#             </span>
#             <article data-nid="3432" role="article">
#              <div>
#               <div class="title">
#                <a href="/actualites/les-risques-auditifs-chez-les-jeunes-dans-le-monde" hreflang="fr">
#                 Les risques auditifs chez les jeunes dans le monde
#                </a>
#               </div>
#               <span class="field field--name-created field--type-created field--label-hidden">
#                28 décembre 2022
#               </span>
#              </div>
#             </article>
#             <article data-nid="3401" role="article">
#              <div>
#               <div class="title">
#                <a href="/actualites/phonak-lumity-nouvelle-generation" hreflang="fr">
#                 Phonak Lumity : la nouvelle plateforme du fabricant suisse qui va illuminer vos coversations
#                </a>
#               </div>
#               <span class="field field--name-created field--type-created field--label-hidden">
#                24 octobre 2022
#               </span>
#              </div>
#             </article>
#             <article data-nid="3396" role="article">
#              <div>
#               <div class="title">
#                <a href="/actualites/resound-omnia-la-nouvelle-generation-dappareils-auditifs-resound" hreflang="fr">
#                 Resound Omnia : la nouvelle génération d'appareils auditifs Resound
#                </a>
#               </div>
#               <span class="field field--name-created field--type-created field--label-hidden">
#                19 octobre 2022
#               </span>
#              </div>
#             </article>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="groupe-2">
#          <a class="faq" href="/faq">
#           FAQ
#          </a>
#          <div class="search-toggle">
#           Recherche
#          </div>
#         </div>
#         <div class="main-menu-icons">
#          <span class="item-prendre_rendez_vous obflink" data-content="Prendre rendez-vous" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8=" data-uuid="ed8d4db2-c0e3-4c7b-91c3-ca60b1d6547e">
#           Prendre rendez-vous
#          </span>
#          <a class="item-trouver_un_centre" data-content="Trouver un centre" data-uuid="60db5e40-dfc4-468a-8b28-7e43eaa3e382" href="/centre-audition">
#           Trouver un centre
#          </a>
#          <a class="item-nous_contacter" data-content="Nous contacter" data-uuid="49d241f6-27da-41da-9a0a-efaed3aa40d2" href="/contact">
#           Nous contacter
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </header>
#     <div class="region region-breadcrumb">
#      <div class="block block-system block-system-breadcrumb-block" id="block-vivason-breadcrumbs">
#       <nav aria-labelledby="system-breadcrumb" class="breadcrumb" role="navigation">
#        <div class="visually-hidden" id="system-breadcrumb">
#         Fil d'Ariane
#        </div>
#        <ol>
#         <li>
#          <a href="/">
#           Accueil
#          </a>
#         </li>
#         <li>
#          Audioprothésistes VivaSon - Trouvez un centre à proximité
#         </li>
#        </ol>
#       </nav>
#      </div>
#     </div>
#     <div class="region region-help">
#      <div class="hidden" data-drupal-messages-fallback="">
#      </div>
#     </div>
#     <main role="main">
#      <a id="main-content" tabindex="-1">
#      </a>
#      <div class="layout-content">
#       <div class="region region-content">
#        <div class="block block-system block-system-main-block" id="block-vivason-content">
#         <h1>
#          Trouver
#          <strong>
#           un centre
#          </strong>
#         </h1>
#         <div>
#          <div class="js-form-item form-item js-form-type-textfield form-type-textfield js-form-item- form-item-">
#           <label>
#            Saisissez le nom d'une ville ou un code postal pour trouver les centres les plus proches
#           </label>
#           <input class="form-text" id="filtre--ville" maxlength="128" placeholder="Exemples : Paris, 75002" size="60" type="text"/>
#          </div>
#          <div class="item-list">
#           <h3>
#            ou filtrer les centres par zone géographique
#           </h3>
#           <ul id="filtre--zone">
#            <li>
#             <a href="#zone:tous">
#              Tous nos centres (
#              <span class="count">
#               70
#              </span>
#              )
#             </a>
#            </li>
#            <li>
#             <a href="#zone:ile-de-france">
#              Ile-de-France (
#              <span class="count">
#               32
#              </span>
#              )
#             </a>
#            </li>
#            <li>
#             <a href="#zone:province">
#              Province (
#              <span class="count">
#               38
#              </span>
#              )
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div id="resultats">
#          <div id="resultats--carte">
#           Activer JavaScript pour voir la carte.
#          </div>
#          <div class="liste-boutiques-wrapper" id="resultats--liste">
#           <article class="boutique" data-dpt="01" data-email="Ym91cmctZW4tYnJlc3NlQHZpdmFzb24uZnI=" data-location='{"lat":46.206833400000001,"lng":5.2262702000000001}' data-nid="2070" data-zone="province" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/bourg-en-bresse">
#               01 - Vivason
#               <strong>
#                Bourg-en-Bresse
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                3 rue René Cassin
#               </span>
#               <br/>
#               <span class="postal-code">
#                01000
#               </span>
#               <span class="locality">
#                Bourg-en-Bresse
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0474451513">
#               04 74 45 15 13
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 12h30
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vRi1CRUI=">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/bourg-en-bresse" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique" data-dpt="06" data-email="bmljZUB2aXZhc29uLmZy" data-location='{"lat":43.7041647,"lng":7.2679410999999998}' data-nid="2080" data-zone="province" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/nice">
#               06 - Vivason
#               <strong>
#                Nice
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                20 avenue Notre-Dame
#               </span>
#               <br/>
#               <span class="postal-code">
#                06000
#               </span>
#               <span class="locality">
#                Nice
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0493011010">
#               04 93 01 10 10
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 12h30
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vTklDRQ==">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/nice" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique" data-dpt="06" data-email="Y2FnbmVzLXN1ci1tZXJAdml2YXNvbi5mcg==" data-location='{"lat":43.662511799999997,"lng":7.1493564000000003}' data-nid="3334" data-zone="province" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/cagnes-sur-mer">
#               06 - Vivason
#               <strong>
#                Cagnes-sur-Mer
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                83 avenue de la gare
#               </span>
#               <br/>
#               <span class="postal-code">
#                06800
#               </span>
#               <span class="locality">
#                Cagnes-sur-Mer
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0497024780">
#               04 97 02 47 80
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 12h30
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vRi1DQUdORVM=">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/cagnes-sur-mer" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique boutique--new" data-dpt="10" data-email="dHJveWVzQHZpdmFzb24uZnI=" data-location='{"lat":48.2977706,"lng":4.0743179999999999}' data-nid="3393" data-zone="province" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/troyes">
#               10 - Vivason
#               <strong>
#                Troyes
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                24 Rue de la République
#               </span>
#               <br/>
#               <span class="postal-code">
#                10000
#               </span>
#               <span class="locality">
#                Troyes
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0310940094">
#               03 10 94 00 94
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 12h30
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vRi1UUk9ZRVM=">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/troyes" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique" data-dpt="13" data-email="bWFyc2VpbGxlQHZpdmFzb24uZnI=" data-location='{"lat":43.286193500000003,"lng":5.3855709999999997}' data-nid="3365" data-zone="province" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/marseille">
#               13 - Vivason
#               <strong>
#                Marseille
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                10 boulevard baille
#               </span>
#               <br/>
#               <span class="postal-code">
#                13006
#               </span>
#               <span class="locality">
#                Marseille
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0491803322">
#               04 91 80 33 22
#              </a>
# ...
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                90 avenue Henri Barbusse
#               </span>
#               <br/>
#               <span class="postal-code">
#                93700
#               </span>
#               <span class="locality">
#                Drancy
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0141501736">
#               01 41 50 17 36
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 18h30
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vRi1EUkFOQ1k=">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/drancy" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique" data-dpt="94" data-email="Y3JldGVpbEB2aXZhc29uLmZy" data-location='{"lat":48.795445600000001,"lng":2.4591645}' data-nid="3346" data-zone="ile-de-france" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/creteil">
#               94 - Vivason
#               <strong>
#                Créteil
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                2 avenue du Maréchal de Lattre de Tassigny
#               </span>
#               <br/>
#               <span class="postal-code">
#                94000
#               </span>
#               <span class="locality">
#                Créteil
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0185600660">
#               01 85 60 06 60
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 12h30
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vRi1DUkVURUlM">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/creteil" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique" data-dpt="94" data-email="dmluY2VubmVzQHZpdmFzb24uZnI=" data-location='{"lat":48.848275399999999,"lng":2.4350849999999999}' data-nid="2073" data-zone="ile-de-france" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/vincennes">
#               94 - Vivason
#               <strong>
#                Vincennes
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                109 rue de Fontenay
#               </span>
#               <br/>
#               <span class="postal-code">
#                94300
#               </span>
#               <span class="locality">
#                Vincennes
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0143684368">
#               01 43 68 43 68
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 12h30
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vVklOQ0VOTkVT">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/vincennes" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique" data-dpt="95" data-email="YXJnZW50ZXVpbEB2aXZhc29uLmZy" data-location='{"lat":48.945854400000002,"lng":2.2496510999999999}' data-nid="2062" data-zone="ile-de-france" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/argenteuil">
#               95 - Vivason
#               <strong>
#                Argenteuil
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                76 avenue Gabriel Péri
#               </span>
#               <br/>
#               <span class="postal-code">
#                95100
#               </span>
#               <span class="locality">
#                Argenteuil
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0134340660">
#               01 34 34 06 60
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 19h00
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vQVJHRU5URVVJTA==">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/argenteuil" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique" data-dpt="95" data-email="b3NueUB2aXZhc29uLmZy" data-location='{"lat":49.056252299999997,"lng":2.0332083999999999}' data-nid="2775" data-zone="ile-de-france" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/cergy-pontoise-osny">
#               95 - Vivason
#               <strong>
#                Cergy-Pontoise (Osny)
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                16 rue du Petit Albi
#               </span>
#               <br/>
#               <span class="address-line2">
#                Centre de Santé
#               </span>
#               <br/>
#               <span class="postal-code">
#                95520
#               </span>
#               <span class="locality">
#                Osny
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0180927130">
#               01 80 92 71 30
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 13h00
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vRi1PU05Z">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/cergy-pontoise-osny" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#           <article class="boutique" data-dpt="95" data-email="ZW5naGllbkB2aXZhc29uLmZy" data-location='{"lat":48.971975200000003,"lng":2.3092027000000002}' data-nid="2084" data-zone="ile-de-france" role="article">
#            <div>
#             <h2 class="title">
#              <a href="/centre-audition/enghien-les-bains">
#               95 - Vivason
#               <strong>
#                Enghien-les-Bains
#               </strong>
#              </a>
#             </h2>
#             <div class="field field--name-field-adresse field--type-address field--label-hidden field__item">
#              <p class="address" translate="no">
#               <span class="address-line1">
#                15 rue du Général de Gaulle
#               </span>
#               <br/>
#               <span class="postal-code">
#                95880
#               </span>
#               <span class="locality">
#                Enghien-Les-Bains
#               </span>
#               <br/>
#               <span class="country">
#                France
#               </span>
#              </p>
#             </div>
#             <div class="field field--name-field-telephone field--type-telephone field--label-hidden field__item">
#              <a href="tel:0139640909">
#               01 39 64 09 09
#              </a>
#             </div>
#             <div class="statut-boutique statut-green">
#              Ouvert jusqu'à 18h30
#             </div>
#             <div class="cta">
#              <span class="obflink" data-o="L2Rpc3BvbmliaWxpdGUtZGVzLWNlbnRyZXMtYXVkaW8vRU5HSElFTg==">
#               Prendre RDV
#              </span>
#              <a class="fiche-magasin" href="/centre-audition/enghien-les-bains" hreflang="fr">
#               Fiche magasin
#              </a>
#             </div>
#            </div>
#           </article>
#          </div>
#         </div>
#        </div>
#        <div class="widget-form-contact block block-vivason-common block-vivason-form-contact-widget" id="block-vivasonwidgetformulairecontact">
#         <div>
#          <a class="button-open use-ajax" data-dialog-options='{"title":"Contactez-nous","width":"720","dialogClass":"contact-widget"}' data-dialog-type="modal" href="/form/contact-widget" id="button-open">
#           <span class="text">
#            Une question ? Contactez nous
#           </span>
#          </a>
#          <div class="wrapper-webform" id="wrapper-webform">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </main>
#     <footer role="contentinfo">
#      <div class="region region-footer">
#       <div class="pied-de-page block block-vivason-common block-vivason-menu-pied-de-page" id="block-vivasonmenupieddepage">
#        <div>
#         <img alt="" class="vivason-vivason-logo.png" src="/themes/custom/vivason/assets/images/vivason-logo.png"/>
#         <div class="Colonne 1">
#          <ul class="menu">
#           <li class="menu-item menu-item--active-trail">
#            <a class="is-active" data-drupal-link-system-path="centre-audition" href="/centre-audition">
#             Nos centres
#            </a>
#           </li>
#           <li class="menu-item">
#            <span class="obflink" data-o="L3F1aS1zb21tZXMtbm91cy9ub3RyZS1oaXN0b2lyZQ==">
#             Qui sommes-nous ?
#            </span>
#           </li>
#           <li class="menu-item">
#            <span class="obflink" data-o="L21lbnRpb25zLWxlZ2FsZXM=">
#             Mentions légales
#            </span>
#           </li>
#          </ul>
#          <a href="javascript:openAxeptioCookies()">
#           Modifier mes préférences
#           <br/>
#           en matière de cookies
#          </a>
#         </div>
#         <div class="Colonne 2">
#          <ul class="menu">
#           <li class="menu-item">
#            <a data-drupal-link-system-path="node/2733" href="/appareil-auditif">
#             Guide appareil auditif
#            </a>
#           </li>
#           <li class="menu-item">
#            <a data-drupal-link-system-path="node/2746" href="/votre-audition">
#             Votre audition
#            </a>
#           </li>
#           <li class="menu-item">
#            <span class="obflink" data-o="L2NvbmRpdGlvbnMtZ2VuZXJhbGVzLWRlLXZlbnRl">
#             Conditions générales de vente
#            </span>
#           </li>
#           <li class="menu-item">
#            <span class="obflink" data-o="L2NvbnRlbnQvcmVjcnV0ZW1lbnQ=">
#             Nous rejoindre
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="Colonne 3">
#          <ul class="menu">
#           <li class="menu-item">
#            <a data-drupal-link-system-path="nos-appareils-auditifs" href="/nos-appareils-auditifs">
#             Nos appareils auditifs
#            </a>
#           </li>
#           <li class="menu-item">
#            <a data-drupal-link-system-path="actualites" href="/actualites">
#             Les actualités
#            </a>
#           </li>
#           <li class="menu-item">
#            <span class="obflink" data-o="L2NvbnRlbnQvcG9saXRpcXVlLWRlLWNvbmZpZGVudGlhbGl0ZQ==">
#             Politique de confidentialité
#            </span>
#           </li>
#           <li class="menu-item">
#            <span class="obflink" data-o="L2NvbnRhY3Q=">
#             Nous contacter
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="vivason-reseaux-sociaux">
#          <div class="title">
#           Suivez-nous sur
#          </div>
#          <div class="list">
#           <div class="vivason-facebook-icon.svg obflink" data-o="aHR0cHM6Ly93d3cuZmFjZWJvb2suY29tL1ZpdmFTb25BdWRpdGlvbg==">
#            <img alt="" src="/themes/custom/vivason/assets/images/facebook-icon.svg"/>
#           </div>
#           <div class="vivason-twitter-icon.svg obflink" data-o="aHR0cHM6Ly90d2l0dGVyLmNvbS92aXZhc29uYXVkaXRpb24/bGFuZz1mcg==">
#            <img alt="" src="/themes/custom/vivason/assets/images/twitter-icon.svg"/>
#           </div>
#           <div class="vivason-linkedIn-icon.svg obflink" data-o="aHR0cHM6Ly93d3cubGlua2VkaW4uY29tL2NvbXBhbnkvdml2YXNvbi8=">
#            <img alt="" src="/themes/custom/vivason/assets/images/linkedIn-icon.svg"/>
#           </div>
#          </div>
#         </div>
#         <div class="vivason-copyright">
#          © Vivason 2020 tous droits réservés
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TQV7BFP" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script data-drupal-selector="drupal-settings-json" type="application/json">
#    {"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"centre-audition","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"fr"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"classy\/base,classy\/messages,core\/normalize,core\/picturefill,system\/base,vivason\/global-styling,vivason_common\/store_locator,vivason_common\/widget-form-contact","theme":"vivason","theme_token":null},"ajaxTrustedUrl":[],"field_group":{"html_element":{"mode":"teaser","context":"view","settings":{"classes":"cta","id":"","element":"div","show_label":false,"label_element":"h3","label_element_classes":"","attributes":"","effect":"none","speed":"fast"}}},"user":{"uid":0,"permissionsHash":"432172bcf252263a1d99e4b1f0698fecf3610d572ba60ed98d66fe206a7f4f52"}}
#   </script>
#   <script src="/sites/default/files/js/js_zR_BB1MMf7BQH3gjRvSvxdneyX9cKm0PoD5DGySSGHw.js">
#   </script>
#   <script async="" src="//maps.googleapis.com/maps/api/js?key=AIzaSyB-a3XS8Lrzi6IJ3GrwKdngtc0CXFb84kU&amp;libraries=places,geometry&amp;callback=vivasonStoreLocator.init">
#   </script>
#  </body>
# </html>

# %%
store_tags = soup.find_all('article', {'class':"boutique"})

def decode_store_item(tag):
    name = tag.find('h2', {'class': 'title'}).get_text().strip('\n')
    address = ' '.join(tag.find('div', {'class':"field field--name-field-adresse field--type-address field--label-hidden field__item"}).get_text().split('\n'))
    return name, address

decode_store_item(store_tags[0])
# Out:
# ('01 - Vivason Bourg-en-Bresse',
#  '3 rue René Cassin 01000 Bourg-en-Bresse France')

# %%
res = [decode_store_item(tag) for tag in store_tags]
df = pd.DataFrame(res, columns=['shop_name', 'address'])

# %%
# geolocate shops
geolocator = IGNFrance()

df['latitude'] = np.nan
df['longitude'] = np.nan
df['city'] = np.nan
df['postcode'] = np.nan

for i in df.index:

    if ((i>0) and (i%50==0)):
        print(f'{i}/{len(df)}')

    try:
        #tries fetch address from geopy
        location = geolocator.geocode(df['address'][i], timeout=None)
        
        #append lat/long to column using dataframe location
        df.loc[i,'latitude'] = float(location.latitude)
        df.loc[i,'longitude'] = float(location.longitude)
        df.loc[i,'city'] = location.raw['commune']
        df.loc[i,'postcode'] = location.raw['postal_code']
        
    except:
        continue
# Out:
# 50/70

# %%
# check
df.head()
# Out:
#                       shop_name  \
# 0  01 - Vivason Bourg-en-Bresse
# 1             06 - Vivason Nice
# 2   06 - Vivason Cagnes-sur-Mer
# 3           10 - Vivason Troyes
# 4        13 - Vivason Marseille
#
#                                             address   latitude  longitude  \
# 0    3 rue René Cassin 01000 Bourg-en-Bresse France  46.206821   5.226367
# 1            20 avenue Notre-Dame 06000 Nice France  43.704077   7.268075
# 2  83 avenue de la gare 06800 Cagnes-sur-Mer France  43.662502   7.149372
# 3       24 Rue de la République 10000 Troyes France  48.297710   4.074422
# 4        10 boulevard baille 13006 Marseille France  43.286254   5.385543
#
#               city postcode
# 0  Bourg-en-Bresse    01000
# 1             Nice    06000
# 2   Cagnes-sur-Mer    06800
# 3           Troyes    10000
# 4        Marseille    13006

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  70 non-null     object
#  1   address    70 non-null     object
#  2   latitude   70 non-null     float64
#  3   longitude  70 non-null     float64
#  4   city       70 non-null     object
#  5   postcode   70 non-null     object
# dtypes: float64(2), object(4)
# memory usage: 3.4+ KB

# %%
df.to_csv('../output/vivason_shops_geocoded.csv', index=False)
