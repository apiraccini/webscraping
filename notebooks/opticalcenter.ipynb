# %%
import urllib3
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from geopy.geocoders import IGNFrance

# %%
page = urllib3.PoolManager().request('GET', 'https://audition.optical-center.fr/fr?page=2')
soup = BeautifulSoup(page.data, features="html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="fr">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="HgeEavIQVdE8GJw1FWs56DHVvN-zm9HAP6a7NoZ8sJ8" name="google-site-verification"/>
#   <title>
#    Centre audition France : appareils et prothèses auditives - Page 2 de 35
#   </title>
#   <meta content="Centre audition France : appareils et prothèses auditives - Page 2 de 35" name="title"/>
#   <meta content="Optical Center centre audition France : appareils auditifs et prothèses auditives. Trouvez l'aide auditive adaptée à vos troubles de l'audition parmi les plus grandes marques de prothèse auditive : Siemens, Oticon, Widex... - Page 2 de 35" name="description"/>
#   <link href="https://audition.optical-center.fr/fr" rel="prev"/>
#   <link href="https://audition.optical-center.fr/fr?page=3" rel="next"/>
#   <link href="https://audition.optical-center.fr/fr?page=2" hreflang="x-default" rel="alternate">
#    <link href="https://audition.optical-center.fr/fr?page=2" hreflang="fr" rel="alternate">
#     <link href="https://hearing.optical-center.co.uk/fr?page=2" hreflang="en" rel="alternate"/>
#     <link href="https://hearing.optical-center.quebec/fr?page=2" hreflang="en-CA" rel="alternate"/>
#     <link href="https://audicion.optical-center.es/fr?page=2" hreflang="es" rel="alternate"/>
#     <link href="https://audition.optical-center.quebec/fr?page=2" hreflang="fr-CA" rel="alternate"/>
#     <link href="https://hearing.optical-center.co.il/fr?page=2" hreflang="he" rel="alternate"/>
#     <link href="https://audition.optical-center.be/fr?page=2" hreflang="nl" rel="alternate"/>
#     <link href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/humans.txt" rel="author"/>
#     <link href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/build/geo-divisions.min.css" rel="stylesheet" title="main"/>
#     <link disabled="" href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/build/geo-divisions-wcag.min.css" rel="stylesheet" title="wcag"/>
#     <link href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#     <link href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#     <link href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#     <link href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/favicon/site.webmanifest" rel="manifest"/>
#     <link color="#333333" href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
#     <link href="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/favicon/favicon.ico" rel="shortcut icon"/>
#     <meta content="#333333" name="msapplication-TileColor"/>
#     <meta content="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/favicon/browserconfig.xml" name="msapplication-config"/>
#     <meta content="#333333" name="theme-color"/>
#     <!-- AT-Internet 629632 -->
#     <script data-vendor="c:atinternet" type="didomi/javascript">
#      const script = document.createElement('script');
#             script.src = "//tag.aticdn.net/629632/smarttag.js";
#             script.addEventListener('load', () => {
#                 if (typeof ATInternet !== 'undefined') {
#                     window.tag = new ATInternet.Tracker.Tag();
#                     window.tag.page = '/fr?page=2';
#                     window.tag.level = 'FR';
#                     window.tag.internal = '';
#                     window.tag.events.send('page.display', {
#                         'page': window.tag.page,
#                         'site_level2': window.tag.level,
#                         'internal_traffic': !!window.tag.internal
#                     });
#                 }
#             });
#
#             document.head.appendChild(script);
#     </script>
#     <!-- Google Tag Manager GTM-MB8MXZ -->
#     <script>
#      (function(w,d,s,l,i){
#                 w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#                 var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#                 j.async=true; j.defer=true; j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
#                 f.parentNode.insertBefore(j,f);
#             })
#             (window,document,'script','dataLayer','GTM-MB8MXZ');
#     </script>
#     <!-- Google Tag Manager GTM-NG79HLS -->
#     <script>
#      (function(w,d,s,l,i){
#                 w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#                 var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#                 j.async=true; j.defer=true; j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
#                 f.parentNode.insertBefore(j,f);
#             })
#             (window,document,'script','dataLayer','GTM-NG79HLS');
#     </script>
#    </link>
#   </link>
#  </head>
#  <body data-bridge-tracking-client-id="5c920e6cd153ae0412b44ed5" data-bridge-tracking-env="production-front-offices" data-bridge-tracking-front-office-id="5c920e6c9caec61192693150" data-bridge-tracking-locale="fr" data-bridge-tracking-location-id="" id="lf-body">
#   <!-- Google Tag Manager noscript GTM-MB8MXZ -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MB8MXZ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- Google Tag Manager noscript GTM-NG79HLS -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NG79HLS" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div id="lf-body-large-wrapper">
#    <ul class="lf-skip-content">
#     <li class="lf-skip-content__item">
#      <a class="lf-skip-content__item__link" data-lf-tracking='{"bind":"click","label":"search","action":"","category":"Skip to Content"}' href="#lf-search">
#       Aller à la recherche
#      </a>
#     </li>
#     <li class="lf-skip-content__item">
#      <a class="lf-skip-content__item__link" data-lf-tracking='{"bind":"click","label":"content","action":"","category":"Skip to Content"}' href="#lf-content">
#       Aller au contenu
#      </a>
#     </li>
#     <li class="lf-skip-content__item">
#      <a class="lf-skip-content__item__link" data-lf-tracking='{"bind":"click","label":"footer","action":"","category":"Skip to Content"}' href="#lf-footer">
#       Aller au footer
#      </a>
#     </li>
#    </ul>
#    <section aria-describedby="description-notification" aria-labelledby="title-notification" class="lf-notification-default inactive" data-lf-notification="" role="alert">
#     <div class="lf-notification-default--nowrapper">
#      <em aria-hidden="true" class="lf-notification-default__icon" data-lf-notification-icon="">
#      </em>
#      <p class="lf-notification-default__title" data-lf-notification-title="" id="title-notification">
#      </p>
#      <p class="lf-notification-default__message" data-lf-notification-msg="" id="description-notification">
#      </p>
#     </div>
#    </section>
#    <header data-lf-header="">
#     <nav class="lf-header-client" data-lf-top-fixed="" id="lf-header-client">
#      <div class="lf-header-client--fixed">
#       <div class="lf-header-client__main lf-header-client__main--no-container">
#        <a class="lf-header-client__main__logo" data-lf-header-logo="" data-lf-tracking='{"bind":"click","label":"logo Optical Center","action":"","category":"Header External Links"}' href="/">
#         <img alt="Logo Optical Center" class="lf-header-client__main__logo__image" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/client/logo-oc.svg"/>
#        </a>
#        <div aria-expanded="false" aria-haspopup="true" class="lf-header-client__main__toggler" data-lf-expand-header="true" data-lf-hamburger="" role="button" tabindex="0">
#         <div class="lf-header-client__main__toggler__hamburger" id="lf-header-menu">
#          <div class="lf-header-client__main__toggler__hamburger__icon">
#           <div class="lf-header-client__main__toggler__hamburger__icon__bar lf-header-client__main__toggler__hamburger__icon__bar--top">
#           </div>
#           <div class="lf-header-client__main__toggler__hamburger__icon__bar lf-header-client__main__toggler__hamburger__icon__bar--top-mid">
#           </div>
#           <div class="lf-header-client__main__toggler__hamburger__icon__bar lf-header-client__main__toggler__hamburger__icon__bar--bottom-mid">
#           </div>
#           <div class="lf-header-client__main__toggler__hamburger__icon__bar lf-header-client__main__toggler__hamburger__icon__bar--bottom">
#           </div>
#          </div>
#          <span class="lf-header-client__main__toggler__hamburger__sr-only">
#           Menu
#          </span>
#         </div>
#        </div>
#        <div class="lf-header-client__main__menu lf-hidden" data-lf-header-menu="" id="lf-header-nav">
#         <div class="lf-header-client__main__menu__content" data-lf-header-menu-items="">
#          <ul class="lf-header-client__main__menu__content__list">
#           <li class="lf-header-client__main__menu__content__list__item" data-lf-header-menu-item="">
#            <a class="lf-header-client__main__menu__content__list__item__link" data-lf-header-menu-item-link="" data-lf-tracking='{"bind":"click","label":"Notre regard","action":"","category":"Header External Links"}' href="https://www.optical-center.fr/notre-regard" rel="noopener" target="_blank">
#             Notre regard
#            </a>
#           </li>
#           <li class="lf-header-client__main__menu__content__list__item" data-lf-header-menu-item="">
#            <a class="lf-header-client__main__menu__content__list__item__link" data-lf-header-menu-item-link="" data-lf-tracking='{"bind":"click","label":"Notre offre optique","action":"","category":"Header External Links"}' href="https://www.optical-center.fr/notre-offre-optique" rel="noopener" target="_blank">
#             Notre offre optique
#            </a>
#           </li>
#           <li class="lf-header-client__main__menu__content__list__item" data-lf-header-menu-item="">
#            <a class="lf-header-client__main__menu__content__list__item__link" data-lf-header-menu-item-link="" data-lf-tracking='{"bind":"click","label":"Notre offre audition","action":"","category":"Header External Links"}' href="https://www.optical-center.fr/notre-offre-audition" rel="noopener" target="_blank">
#             Notre offre audition
#            </a>
#           </li>
#           <li class="lf-header-client__main__menu__content__list__item" data-lf-header-menu-item="">
#            <a class="lf-header-client__main__menu__content__list__item__link" data-lf-header-menu-item-link="" data-lf-tracking='{"bind":"click","label":"Rejoignez-nous","action":"","category":"Header External Links"}' href="https://www.optical-center.fr/rejoignez-nous" rel="noopener" target="_blank">
#             Rejoignez-nous
#            </a>
#           </li>
#          </ul>
#          <ul class="lf-header-client__main__menu__content__list">
#           <li class="lf-header-client__main__menu__content__list__item" data-lf-header-menu-item="">
#            <a class="lf-header-client__main__menu__content__list__item__link" data-lf-header-menu-item-link="" data-lf-tracking='{"bind":"click","label":"Espace fidelit\u00e9 magasins","action":"","category":"Header External Links"}' href="https://www.optical-center.fr/espace-fidelite/login" rel="noopener" target="_blank">
#             <img alt="" class="lf-header-client__main__menu__content__list__item__link__icon" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/header/espace-fidelite.svg">
#              <span>
#               Espace fidelité magasins
#              </span>
#             </img>
#            </a>
#           </li>
#           <li class="lf-header-client__main__menu__content__list__item" data-lf-header-menu-item="">
#            <a class="lf-header-client__main__menu__content__list__item__link" data-lf-header-menu-item-link="" data-lf-tracking='{"bind":"click","label":"Inscription newsletter","action":"","category":"Header External Links"}' href="https://www.optical-center.fr/inscription-newsletter" rel="noopener" target="_blank">
#             <img alt="" class="lf-header-client__main__menu__content__list__item__link__icon" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/header/newsletter.svg"/>
#             <span>
#              Inscription newsletter
#             </span>
#            </a>
#           </li>
#           <li class="lf-header-client__main__menu__content__list__item" data-lf-header-menu-item="">
#            <a class="lf-header-client__main__menu__content__list__item__link" data-lf-header-menu-item-link="" data-lf-tracking='{"bind":"click","label":"Actualit\u00e9s","action":"","category":"Header External Links"}' href="https://www.optical-center.fr/actualites" rel="noopener" target="_blank">
#             <img alt="" class="lf-header-client__main__menu__content__list__item__link__icon" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/header/actus.svg"/>
#             <span>
#              Actualités
#             </span>
#            </a>
#           </li>
#           <li class="lf-header-client__main__menu__content__list__item" data-lf-header-menu-item="">
#            <a class="lf-header-client__main__menu__content__list__item__link" data-lf-header-menu-item-link="" data-lf-tracking='{"bind":"click","label":"Boutique en ligne","action":"","category":"Header External Links"}' href="https://www.optical-center.fr/" rel="noopener" target="_blank">
#             <img alt="" class="lf-header-client__main__menu__content__list__item__link__icon" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/header/hand-bag.svg"/>
#             <span>
#              Boutique en ligne
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="lf-header-client__main__end">
#         <div class="lf-header-client__main__end__links">
#          <a class="lf-cta-link lf-header-client__main__end__links__item" data-lf-tracking='{"bind":"click","label":"Online store","action":"","category":"Header"}' href="https://www.optical-center.fr/" rel="noopener" target="_blank">
#           <em aria-hidden="true" class="lf-cta-link__icon lf-cta-link__icon--left optical-icon-hand-bag lf-header-client__main__end__links__item__icon lf-header-client__main__end__links__item__icon--left">
#           </em>
#           <span class="lf-cta-link__label lf-header-client__main__end__links__item__label">
#            Boutique en ligne
#           </span>
#          </a>
#          <div class="lf-header-client__main__end__links__more">
#          </div>
#         </div>
#         <div class="lf-header-lang lf-header-client__main__end__lang" data-lf-header-lang="" id="lf-header-lang">
#          <span class="lf-header-lang__wcag" id="lf-header-lang-helper">
#           Changer la langue
#          </span>
#          <button class="lf-header-lang__toggle lf-header-client__main__end__lang__toggle" data-micromodal-trigger="modal-lang" id="lf-header-lang-btn" type="button">
#           <span class="lf-header-lang__toggle__trigger lf-header-client__main__end__lang__toggle__trigger">
#            <span class="lf-header-lang__toggle__trigger__icon lf-header-client__main__end__lang__toggle__trigger__icon">
#             <img alt="" class="lf-header-lang__toggle__trigger__icon__img lf-header-client__main__end__lang__toggle__trigger__icon__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/client/lang/lang-fr.svg"/>
#            </span>
#            <span class="lf-header-lang__toggle__trigger__locale lf-header-client__main__end__lang__toggle__trigger__locale">
#             <span>
#              Français
#             </span>
#            </span>
#            <span class="lf-header-lang__toggle__trigger__caret lf-header-client__main__end__lang__toggle__trigger__caret">
#            </span>
#           </span>
#          </button>
#          <div aria-hidden="true" class="lf-modal-default lf-header-lang__modal" id="modal-lang">
#           <div class="lf-modal-default__container lf-header-lang__modal__container" data-micromodal-close="" tabindex="-1">
#            <section aria-labelledby="modal-lang-title" aria-live="assertive" aria-modal="true" class="lf-modal-default__container__content lf-header-lang__modal__container__content" role="dialog">
#             <div class="lf-modal-default__container__content__header lf-header-lang__modal__container__content__header">
#              <button class="lf-modal-default__container__content__header__close lf-header-lang__modal__container__content__header__close" data-micromodal-close="" type="button">
#               <em class="lf-modal-default__container__content__header__close__icon lf-header-lang__modal__container__content__header__close__icon bridge-icon-essential-close" data-micromodal-close="">
#               </em>
#               <span class="sr-only">
#                Fermer la fenêtre
#               </span>
#              </button>
#              <div class="lf-modal-default__container__content__header__title lf-header-lang__modal__container__content__header__title" id="modal-lang-title">
#               Language
#              </div>
#             </div>
#             <div class="lf-modal-default__container__content__body lf-header-lang__modal__container__content__body" id="modal-lang-content">
#              <ul aria-labelledby="lf-header-lang-btn" class="lf-modal-default__container__content__body__default__list lf-header-lang__modal__container__content__body__default__list" id="lf-header-lang-list">
#               <li class="lf-modal-default__container__content__body__default__list__item lf-header-lang__modal__container__content__body__default__list__item" id="lf-header-lang-item-en" role="none">
#                <a class="lf-modal-default__container__content__body__default__list__item__link lf-header-lang__modal__container__content__body__default__list__item__link" data-lf-tracking='{"bind":"click","label":"en","action":"","category":"Lang switcher"}' href="//hearing.optical-center.co.uk/fr?page=2">
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__icon lf-header-lang__modal__container__content__body__default__list__item__link__icon">
#                  <img alt="" class="lf-modal-default__container__content__body__default__list__item__link__icon__img lf-header-lang__modal__container__content__body__default__list__item__link__icon__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/client/lang/lang-en.svg"/>
#                 </span>
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__label lf-header-lang__modal__container__content__body__default__list__item__link__label">
#                  English
#                 </span>
#                </a>
#               </li>
#               <li class="lf-modal-default__container__content__body__default__list__item lf-header-lang__modal__container__content__body__default__list__item" id="lf-header-lang-item-en_CA" role="none">
#                <a class="lf-modal-default__container__content__body__default__list__item__link lf-header-lang__modal__container__content__body__default__list__item__link" data-lf-tracking='{"bind":"click","label":"en_CA","action":"","category":"Lang switcher"}' href="//hearing.optical-center.quebec/fr?page=2">
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__icon lf-header-lang__modal__container__content__body__default__list__item__link__icon">
#                  <img alt="" class="lf-modal-default__container__content__body__default__list__item__link__icon__img lf-header-lang__modal__container__content__body__default__list__item__link__icon__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/client/lang/lang-en_ca.svg"/>
#                 </span>
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__label lf-header-lang__modal__container__content__body__default__list__item__link__label">
#                  Canadian english
#                 </span>
#                </a>
#               </li>
#               <li class="lf-modal-default__container__content__body__default__list__item lf-header-lang__modal__container__content__body__default__list__item" id="lf-header-lang-item-es" role="none">
#                <a class="lf-modal-default__container__content__body__default__list__item__link lf-header-lang__modal__container__content__body__default__list__item__link" data-lf-tracking='{"bind":"click","label":"es","action":"","category":"Lang switcher"}' href="//audicion.optical-center.es/fr?page=2">
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__icon lf-header-lang__modal__container__content__body__default__list__item__link__icon">
#                  <img alt="" class="lf-modal-default__container__content__body__default__list__item__link__icon__img lf-header-lang__modal__container__content__body__default__list__item__link__icon__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/client/lang/lang-es.svg"/>
#                 </span>
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__label lf-header-lang__modal__container__content__body__default__list__item__link__label">
#                  Español
#                 </span>
#                </a>
#               </li>
#               <li class="lf-modal-default__container__content__body__default__list__item lf-header-lang__modal__container__content__body__default__list__item" id="lf-header-lang-item-fr_CA" role="none">
#                <a class="lf-modal-default__container__content__body__default__list__item__link lf-header-lang__modal__container__content__body__default__list__item__link" data-lf-tracking='{"bind":"click","label":"fr_CA","action":"","category":"Lang switcher"}' href="//audition.optical-center.quebec/fr?page=2">
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__icon lf-header-lang__modal__container__content__body__default__list__item__link__icon">
#                  <img alt="" class="lf-modal-default__container__content__body__default__list__item__link__icon__img lf-header-lang__modal__container__content__body__default__list__item__link__icon__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/client/lang/lang-fr_ca.svg"/>
#                 </span>
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__label lf-header-lang__modal__container__content__body__default__list__item__link__label">
#                  Français canadien
#                 </span>
#                </a>
#               </li>
#               <li class="lf-modal-default__container__content__body__default__list__item lf-header-lang__modal__container__content__body__default__list__item" id="lf-header-lang-item-he" role="none">
#                <a class="lf-modal-default__container__content__body__default__list__item__link lf-header-lang__modal__container__content__body__default__list__item__link" data-lf-tracking='{"bind":"click","label":"he","action":"","category":"Lang switcher"}' href="//hearing.optical-center.co.il/fr?page=2">
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__icon lf-header-lang__modal__container__content__body__default__list__item__link__icon">
#                  <img alt="" class="lf-modal-default__container__content__body__default__list__item__link__icon__img lf-header-lang__modal__container__content__body__default__list__item__link__icon__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/client/lang/lang-he.svg"/>
#                 </span>
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__label lf-header-lang__modal__container__content__body__default__list__item__link__label">
#                  עברית
#                 </span>
#                </a>
#               </li>
#               <li class="lf-modal-default__container__content__body__default__list__item lf-header-lang__modal__container__content__body__default__list__item" id="lf-header-lang-item-nl" role="none">
#                <a class="lf-modal-default__container__content__body__default__list__item__link lf-header-lang__modal__container__content__body__default__list__item__link" data-lf-tracking='{"bind":"click","label":"nl","action":"","category":"Lang switcher"}' href="//audition.optical-center.be/fr?page=2">
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__icon lf-header-lang__modal__container__content__body__default__list__item__link__icon">
#                  <img alt="" class="lf-modal-default__container__content__body__default__list__item__link__icon__img lf-header-lang__modal__container__content__body__default__list__item__link__icon__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/client/lang/lang-nl.png"/>
#                 </span>
#                 <span class="lf-modal-default__container__content__body__default__list__item__link__label lf-header-lang__modal__container__content__body__default__list__item__link__label">
#                  Nederlands
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </div>
#            </section>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </nav>
#    </header>
#    <div id="lf-body-wrapper">
#     <div class="lf">
#      <div class="lf-geo-divisions" data-e2e-geo-divisions="">
#       <div class="lf-breadcrumb-scroll lf-geo-divisions__breadcrumb" id="lf-breadcrumb-scroll">
#        <nav aria-label="Chemin de navigation" class="lf-breadcrumb-scroll__container lf-geo-divisions__breadcrumb__container" data-lf-breadcrumb-container="">
#         <ol class="lf-breadcrumb-scroll__container__list lf-geo-divisions__breadcrumb__container__list" data-lf-breadcrumb-list="">
#          <li class="lf-breadcrumb-scroll__container__list__item lf-geo-divisions__breadcrumb__container__list__item">
#           <a class="lf-breadcrumb-scroll__container__list__item__link lf-geo-divisions__breadcrumb__container__list__item__link" data-lf-tracking='{"bind":"click","label":"Accueil","action":"","category":"Breadcrumb"}' href="/">
#            <span class="lf-breadcrumb-scroll__container__list__item__link__label lf-geo-divisions__breadcrumb__container__list__item__link__label sr-only">
#             Accueil
#            </span>
#            <em aria-hidden="true" class="lf-breadcrumb-scroll__container__list__item__link__icon lf-geo-divisions__breadcrumb__container__list__item__link__icon optical-icon-home">
#            </em>
#           </a>
#          </li>
#          <li class="lf-breadcrumb-scroll__container__list__item lf-geo-divisions__breadcrumb__container__list__item">
#           <span aria-current="page" class="lf-breadcrumb-scroll__container__list__item__label lf-geo-divisions__breadcrumb__container__list__item__label">
#            France
#           </span>
#          </li>
#         </ol>
#        </nav>
#        <div class="lf-breadcrumb-scroll__overlay lf-geo-divisions__breadcrumb__overlay" data-lf-breadcrumb-overlay="">
#        </div>
#       </div>
#       <script type="application/ld+json">
#        {
#     "@context": "http://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [            {
#             "@type": "ListItem",
#             "position": 1,
#             "item": {
#                 "@id": "/",
#                 "name": "Home"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 2,
#             "item": {
#                 "@id": "/fr",
#                 "name": "France"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 3,
#             "item": {
#                 "@id": "/fr/hauts-de-france",
#                 "name": "Hauts-de-France"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 4,
#             "item": {
#                 "@id": "/fr/hauts-de-france/oise",
#                 "name": "Oise"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 5,
#             "item": {
#                 "@id": "/audioprothesiste/fr/crepy-en-valois",
#                 "name": "CREPY EN VALOIS"
#             }
#         },            {
#             "@type": "ListItem",
#             "position": 6,
#             "item": {
#                 "@id": "/823-audioprothesiste-crepy-en-valois-optical-center",
#                 "name": "Audioprothésiste CRÉPY-EN-VALOIS Optical Center"
#             }
#         }    ]
# }
#       </script>
#       <section class="lf-geo-divisions__top" data-lf-search-wrapper="" id="lf-geo-divisions-top">
#        <div class="lf-geo-divisions__top__container">
#         <div class="lf-search-results lf-geo-divisions__top__container__search" id="lf-search">
#          <form action="/search" aria-label="Saisissez le lieu de recherche" class="lf-search-results__form lf-geo-divisions__top__container__search__form" data-lf-search-form="" data-lf-tracking='{"bind":"submit","label":"","action":"","category":"Search"}' id="lf-search-form" role="search">
#           <div class="lf-search-results__form__top lf-geo-divisions__top__container__search__form__top">
#            <div class="lf-search-results__form__top__query icon-prefix lf-geo-divisions__top__container__search__form__top__query">
#             <label class="lf-search-results__form__top__query__label lf-geo-divisions__top__container__search__form__top__query__label" for="lf-search-results-query">
#              Ville, Code Postal
#             </label>
#             <button class="lf-delete-input lf-search-results__form__top__query__reset lf-geo-divisions__top__container__search__form__top__query__reset inactive" data-lf-search-reset="" id="lf-delete-input" type="button">
#              <em class="lf-delete-input__icon lf-search-results__form__top__query__reset__icon lf-geo-divisions__top__container__search__form__top__query__reset__icon bridge-icon-essential-chevron-left">
#              </em>
#              <span class="sr-only">
#               Effacer le champ
#              </span>
#             </button>
#             <input class="lf-search-results__form__top__query__input browser-default lf-geo-divisions__top__container__search__form__top__query__input" data-e2e-search-query="" data-lf-search-query="" id="lf-search-results-query" name="query" placeholder="Ville, Code Postal" type="text" value=""/>
#             <button class="lf-cta-button lf-cta-button--icon lf-search-results__form__top__query__filter lf-geo-divisions__top__container__search__form__top__query__filter" data-lf-search-filter-button="" id="lf-search-filter-toggle" type="button">
#              <em aria-hidden="true" class="lf-cta-button__icon lf-cta-button__icon--left optical-icon-filter lf-search-results__form__top__query__filter__icon lf-search-results__form__top__query__filter__icon--left lf-geo-divisions__top__container__search__form__top__query__filter__icon lf-geo-divisions__top__container__search__form__top__query__filter__icon--left">
#              </em>
#              <span class="lf-cta-button__label sr-only lf-search-results__form__top__query__filter__label lf-geo-divisions__top__container__search__form__top__query__filter__label">
#               Filtrer les résultats
#              </span>
#             </button>
#             <button class="lf-cta-button lf-search-geolocation lf-search-results__form__top__query__geolocation lf-geo-divisions__top__container__search__form__top__query__geolocation" data-lf-geolocation-button="" data-lf-msg-error="Un problème est survenu lors de la géolocalisation" data-lf-msg-timeout="Nous n'arrivons pas à vous géolocaliser" data-lf-msg-title="La géolocalisation a échoué" data-lf-msg-warning="Veuillez activer votre géolocalisation" data-lf-search-geolocation-status="" data-lf-tracking='{"bind":"click","label":"\u00c0 proximit\u00e9","action":"","category":"Search"}' id="lf-search-geolocation" type="button">
#              <em aria-hidden="true" class="lf-cta-button__icon lf-cta-button__icon--left bridge-icon-essential-geolocation lf-search-geolocation__icon lf-search-geolocation__icon--left lf-search-results__form__top__query__geolocation__icon lf-search-results__form__top__query__geolocation__icon--left lf-geo-divisions__top__container__search__form__top__query__geolocation__icon lf-geo-divisions__top__container__search__form__top__query__geolocation__icon--left">
#              </em>
#              <span class="lf-cta-button__label lf-search-geolocation__label lf-search-results__form__top__query__geolocation__label lf-geo-divisions__top__container__search__form__top__query__geolocation__label">
#               À proximité
#              </span>
#              <span class="sr-only">
#               , trouver un point de vente Optical Center
#              </span>
#             </button>
#             <button class="lf-cta-button lf-search-results__form__top__query__submit lf-geo-divisions__top__container__search__form__top__query__submit" data-e2e-search-submit="" type="submit">
#              <em aria-hidden="true" class="lf-cta-button__icon lf-cta-button__icon--left optical-icon-search lf-search-results__form__top__query__submit__icon lf-search-results__form__top__query__submit__icon--left lf-geo-divisions__top__container__search__form__top__query__submit__icon lf-geo-divisions__top__container__search__form__top__query__submit__icon--left">
#              </em>
#              <span class="lf-cta-button__label lf-search-results__form__top__query__submit__label lf-geo-divisions__top__container__search__form__top__query__submit__label">
#               Rechercher
#              </span>
#              <span class="sr-only">
#               un point de vente Optical Center
#              </span>
#             </button>
#             <div class="lf-autocomplete-algolia lf-search-results__form__bottom__algolia lf-geo-divisions__top__container__search__form__bottom__algolia" data-lf-autocomplete="" data-lf-autocomplete-locale="fr">
#              <div class="lf-autocomplete-algolia__dataset lf-search-results__form__bottom__algolia__dataset lf-geo-divisions__top__container__search__form__bottom__algolia__dataset">
#               <div class="lf-autocomplete-algolia__dataset__title lf-search-results__form__bottom__algolia__dataset__title lf-geo-divisions__top__container__search__form__bottom__algolia__dataset__title" data-lf-autocomplete-places-header="">
#                Villes
#               </div>
#               <div class="lf-autocomplete-algolia__dataset__suggestion lf-search-results__form__bottom__algolia__dataset__suggestion lf-geo-divisions__top__container__search__form__bottom__algolia__dataset__suggestion" data-lf-autocomplete-places-suggestion="">
#                <div class="lf-autocomplete-algolia__dataset__suggestion__icon lf-search-results__form__bottom__algolia__dataset__suggestion__icon lf-geo-divisions__top__container__search__form__bottom__algolia__dataset__suggestion__icon">
#                 <em aria-label="type de résultat : places" class="optical-icon-city f-autocomplete-algolia__dataset__suggestion__icon__item lf-search-results__form__bottom__algolia__dataset__suggestion__icon__item lf-geo-divisions__top__container__search__form__bottom__algolia__dataset__suggestion__icon__item" role="img">
#                 </em>
#                </div>
#                <div class="lf-autocomplete-algolia__dataset__suggestion__infos lf-search-results__form__bottom__algolia__dataset_suggestion_infos lf-geo-divisions__top__container__search__form__bottom__algolia__dataset_suggestion_infos">
#                 <span class="lf-autocomplete-algolia__dataset__suggestion__infos__name lf-search-results__form__bottom__algolia__dataset_suggestion_infos__name lf-geo-divisions__top__container__search__form__bottom__algolia__dataset_suggestion_infos__name">
#                  {name}
#                 </span>
#                 <span class="lf-autocomplete-algolia__dataset__suggestion__infos__address lf-search-results__form__bottom__algolia__dataset_suggestion_infos__address lf-geo-divisions__top__container__search__form__bottom__algolia__dataset_suggestion_infos__address">
#                  {postalCode} {country}
#                 </span>
#                </div>
#               </div>
#              </div>
#              <div class="lf-autocomplete-algolia__dataset lf-search-results__form__bottom__algolia__dataset lf-geo-divisions__top__container__search__form__bottom__algolia__dataset">
#               <div class="lf-autocomplete-algolia__dataset__title lf-search-results__form__bottom__algolia__dataset__title lf-geo-divisions__top__container__search__form__bottom__algolia__dataset__title" data-lf-autocomplete-locations-header="">
#                Magasins
#               </div>
#               <div class="lf-autocomplete-algolia__dataset__suggestion lf-search-results__form__bottom__algolia__dataset__suggestion lf-geo-divisions__top__container__search__form__bottom__algolia__dataset__suggestion" data-lf-autocomplete-locations-suggestion="">
#                <div class="lf-autocomplete-algolia__dataset__suggestion__icon lf-search-results__form__bottom__algolia__dataset__suggestion__icon lf-geo-divisions__top__container__search__form__bottom__algolia__dataset__suggestion__icon">
#                 <em aria-label="type de résultat : locations" class="optical-icon-store f-autocomplete-algolia__dataset__suggestion__icon__item lf-search-results__form__bottom__algolia__dataset__suggestion__icon__item lf-geo-divisions__top__container__search__form__bottom__algolia__dataset__suggestion__icon__item" role="img">
#                 </em>
#                </div>
#                <div class="lf-autocomplete-algolia__dataset__suggestion__infos lf-search-results__form__bottom__algolia__dataset_suggestion_infos lf-geo-divisions__top__container__search__form__bottom__algolia__dataset_suggestion_infos">
#                 <span class="lf-autocomplete-algolia__dataset__suggestion__infos__name lf-search-results__form__bottom__algolia__dataset_suggestion_infos__name lf-geo-divisions__top__container__search__form__bottom__algolia__dataset_suggestion_infos__name">
#                  {name}
#                 </span>
#                 <span class="lf-autocomplete-algolia__dataset__suggestion__infos__address lf-search-results__form__bottom__algolia__dataset_suggestion_infos__address lf-geo-divisions__top__container__search__form__bottom__algolia__dataset_suggestion_infos__address">
#                  {city}, {postalCode} {country}
#                 </span>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div aria-labelledby="lf-search-filter-toggle" class="lf-search-results__form__top__filters lf-geo-divisions__top__container__search__form__top__filters" role="listbox">
#             <div class="lf-search-filters" id="lf-search-filters">
#              <div class="lf-search-filters__header lf-geo-divisions__top__container__search__form__top__filters__block__header">
#               <div class="lf-search-filters__header__title lf-geo-divisions__top__container__search__form__top__filters__block__header__title">
#                <span>
#                 Sélectionnez un ou plusieurs filtres de recherche
#                </span>
#               </div>
#              </div>
#              <div class="lf-search-filters__content lf-geo-divisions__top__container__search__form__top__filters__block__content">
#               <div class="lf-search-filters__content__container lf-geo-divisions__top__container__search__form__top__filters__block__content__container">
#                <div class="lf-search-country lf-search-country--fr lf-search-filters__content__container__country lf-geo-divisions__top__container__search__form__top__filters__block__content__container__country" data-lf-search-country="" id="lf-search-country">
#                 <div class="lf-search-country__select lf-search-filters__content__container__country__select lf-geo-divisions__top__container__search__form__top__filters__block__content__container__country__select">
#                  <span class="lf-search-country__select__helper" data-lf-countries-helper="" id="lf-search-country-helper">
#                   Filtrer par pays
#                  </span>
#                  <select data-lf-countries-url="FR" id="country-input" name="countries[]">
#                   <option data-default="true" data-unique="true" value="">
#                    Pays
#                   </option>
#                   <option data-lf-country-code="BE" data-lf-country-text="Belgique" data-unique="true" value="BE">
#                    Belgique
#                   </option>
#                   <option data-lf-country-code="CA" data-lf-country-text="Canada" data-unique="true" value="CA">
#                    Canada
#                   </option>
#                   <option data-lf-country-code="CH" data-lf-country-text="Suisse" data-unique="true" value="CH">
#                    Suisse
#                   </option>
#                   <option data-lf-country-code="ES" data-lf-country-text="Espagne" data-unique="true" value="ES">
#                    Espagne
#                   </option>
#                   <option data-lf-country-code="FR" data-lf-country-text="France" data-unique="true" value="FR">
#                    France
#                   </option>
#                   <option data-lf-country-code="GB" data-lf-country-text="Royaume-Uni" data-unique="true" value="GB">
#                    Royaume-Uni
#                   </option>
#                   <option data-lf-country-code="IL" data-lf-country-text="Israël" data-unique="true" value="IL">
#                    Israël
#                   </option>
#                   <option data-lf-country-code="LU" data-lf-country-text="Luxembourg" data-unique="true" value="LU">
#                    Luxembourg
#                   </option>
#                   <option data-lf-country-code="MQ" data-lf-country-text="Martinique" data-unique="true" value="MQ">
#                    Martinique
#                   </option>
#                   <option data-lf-country-code="RE" data-lf-country-text="La Réunion" data-unique="true" value="RE">
#                    La Réunion
#                   </option>
#                  </select>
#                 </div>
#                </div>
#                <div class="lf-search-filters__content__container__list lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list" role="listbox">
#                 <div class="lf-search-filters__content__container__list__item lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item" role="option">
#                  <input class="lf-search-filters__content__container__list__item__input lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item__input" data-lf-filters-input="" id="61e576ad320c380d76a918a9" name="filters[Typologie magasin][]" type="checkbox" value="61e576ad320c380d76a918a9"/>
#                  <label class="lf-search-filters__content__container__list__item__label lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item__label" data-lf-filters-label="" for="61e576ad320c380d76a918a9">
#                   <em aria-labelledby="61e576ad320c380d76a918a9" class="lf-search-filters__content__container__list__item__label__icon lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item__label__icon" role="img">
#                   </em>
#                   <span class="lf-search-filters__content__container__list__item__label__text lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item__label__text">
#                    Optique &amp; Audition
#                   </span>
#                  </label>
#                 </div>
#                 <div class="lf-search-filters__content__container__list__item lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item" role="option">
#                  <input class="lf-search-filters__content__container__list__item__input lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item__input" data-lf-filters-input="" id="61e576ad320c387734a918aa" name="filters[Typologie magasin][]" type="checkbox" value="61e576ad320c387734a918aa"/>
#                  <label class="lf-search-filters__content__container__list__item__label lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item__label" data-lf-filters-label="" for="61e576ad320c387734a918aa">
#                   <em aria-labelledby="61e576ad320c387734a918aa" class="lf-search-filters__content__container__list__item__label__icon lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item__label__icon" role="img">
#                   </em>
#                   <span class="lf-search-filters__content__container__list__item__label__text lf-geo-divisions__top__container__search__form__top__filters__block__content__container__list__item__label__text">
#                    Service à domicile
#                   </span>
#                  </label>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="lf-search-results__form__top__coordinates lf-geo-divisions__top__container__search__form__top__coordinates">
#             <input data-lf-search-latitude="" name="lat" type="hidden" value=""/>
#             <input data-lf-search-longitude="" name="lon" type="hidden" value=""/>
#             <input data-lf-search-geo="" name="geo" type="hidden" value="0"/>
#            </div>
#           </div>
#          </form>
#         </div>
#        </div>
#       </section>
#       <section id="lf-content">
#        <div class="lf-geo-divisions__facets">
#         <div class="lf-geo-divisions__facets__wrapper">
#          <h1 class="lf-geo-divisions__facets__wrapper__title">
#           700 magasins
#           <span>
#            en France
#           </span>
#          </h1>
#          <div class="lf-facets-default lf-geo-divisions__main__facets" id="lf-facets-default">
#           <button aria-controls="lf-facets-default-list" aria-expanded="false" aria-haspopup="true" class="lf-facets-default__button lf-geo-divisions__main__facets__button" data-lf-facets-toggler="">
#            <span class="lf-facets-default__button__label lf-geo-divisions__main__facets__button__label">
#             Régions
#            </span>
# ...
#                on
#               </span>
#               <span class="lf-wcag-contrast__label__off lf-footer-gdpr__container__list__item__link__label__off lf-footer-client__main__bottom__gdpr__container__list__item__link__label__off">
#                off
#               </span>
#               )
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <ul class="lf-footer-client__main__bottom__social">
#          <li class="lf-footer-client__main__bottom__social__item">
#           <a class="lf-footer-client__main__bottom__social__item__link lf-footer-client__main__bottom__social__item__link--facebook" data-lf-tracking='{"bind":"click","label":"facebook","action":"","category":"Footer Social Links"}' href="http://www.facebook.com/Officiel.OpticalCenter" rel="noopener" target="_blank">
#            <span class="sr-only">
#             Aller sur la page facebook de Optical Center
#            </span>
#            <em aria-hidden="true" class="lf-footer-client__main__bottom__social__item__link__icon bridge-icon-brand-facebook" role="img">
#            </em>
#           </a>
#          </li>
#          <li class="lf-footer-client__main__bottom__social__item">
#           <a class="lf-footer-client__main__bottom__social__item__link lf-footer-client__main__bottom__social__item__link--tiktok" data-lf-tracking='{"bind":"click","label":"tiktok","action":"","category":"Footer Social Links"}' href="https://www.tiktok.com/@opticalcenter_?lang=fr" rel="noopener" target="_blank">
#            <span class="sr-only">
#             Aller sur la page tiktok de Optical Center
#            </span>
#            <em aria-hidden="true" class="lf-footer-client__main__bottom__social__item__link__icon bridge-icon-brand-tiktok" role="img">
#            </em>
#           </a>
#          </li>
#          <li class="lf-footer-client__main__bottom__social__item">
#           <a class="lf-footer-client__main__bottom__social__item__link lf-footer-client__main__bottom__social__item__link--youtube" data-lf-tracking='{"bind":"click","label":"youtube","action":"","category":"Footer Social Links"}' href="http://www.youtube.com/OpticalCenterTV" rel="noopener" target="_blank">
#            <span class="sr-only">
#             Aller sur la page youtube de Optical Center
#            </span>
#            <em aria-hidden="true" class="lf-footer-client__main__bottom__social__item__link__icon bridge-icon-brand-youtube" role="img">
#            </em>
#           </a>
#          </li>
#          <li class="lf-footer-client__main__bottom__social__item">
#           <a class="lf-footer-client__main__bottom__social__item__link lf-footer-client__main__bottom__social__item__link--instagram" data-lf-tracking='{"bind":"click","label":"instagram","action":"","category":"Footer Social Links"}' href="https://www.instagram.com/opticalcenter_/" rel="noopener" target="_blank">
#            <span class="sr-only">
#             Aller sur la page instagram de Optical Center
#            </span>
#            <em aria-hidden="true" class="lf-footer-client__main__bottom__social__item__link__icon bridge-icon-brand-instagram" role="img">
#            </em>
#           </a>
#          </li>
#          <li class="lf-footer-client__main__bottom__social__item">
#           <a class="lf-footer-client__main__bottom__social__item__link lf-footer-client__main__bottom__social__item__link--pinterest" data-lf-tracking='{"bind":"click","label":"pinterest","action":"","category":"Footer Social Links"}' href="https://www.pinterest.fr/opticalCenter" rel="noopener" target="_blank">
#            <span class="sr-only">
#             Aller sur la page pinterest de Optical Center
#            </span>
#            <em aria-hidden="true" class="lf-footer-client__main__bottom__social__item__link__icon bridge-icon-brand-pinterest" role="img">
#            </em>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="lf-footer-client__main__logo">
#         <img alt="Logo Optical Center" class="lf-footer-client__main__logo__img" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/footer/logo-oc-footer.svg"/>
#         <span class="lf-footer-client__main__logo__label">
#          Optical Center © Copyright  2023
#         </span>
#         <a class="lf-footer-client__main__logo__copyright" data-lf-tracking='{"bind":"click","label":"Bridge","action":"","category":"Copyright"}' href="https://www.solocal.com/solutions-pour-reseaux/store-locator" rel="noopener" target="_blank">
#          <span class="lf-footer-client__main__logo__copyright__text">
#           Store Locator
#          </span>
#          <img alt="Bridge par Solocal" class="lf-footer-client__main__logo__copyright__logo" src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/assets/images/footer/logo_bridge.svg"/>
#          <span class="lf-footer-client__main__logo__copyright__span sr-only">
#           (ouvre dans une nouvelle fenêtre)
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#    <div class="lf-graphical-overlay-layer lf-graphical-overlay" data-lf-overlay-layer="" id="lf-graphical-overlay-layer">
#     <div class="lf-graphical-loader lf-graphical-overlay-layer__loader lf-graphical-overlay__loader" data-lf-loader="" id="lf-graphical-loader">
#      <div class="lf-graphical-loader__ellipsis lf-graphical-overlay-layer__loader__ellipsis lf-graphical-overlay__loader__ellipsis">
#       <div>
#       </div>
#       <div>
#       </div>
#       <div>
#       </div>
#       <div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    window.noZensmooth = true
#   </script>
#   <script src="https://storage.leadformance.com/assets/production-front-offices/v3-opticalCenterAudioprothesiste/v0.12.1/build/geo-divisions.min.js">
#   </script>
#   <!-- Didomi config -->
#   <script type="text/javascript">
#    window.didomiConfig = {"languages":{"default":"en","enabled":["en","fr"]},"app":{"name":"Optical Center","privacyPolicyURL":"https:\/\/www.optical-center.fr\/Charte-de-donnees-personnelles","vendors":{"custom":[{"id":"bridge","name":"Bridge","policyUrl":"https:\/\/www.optical-center.fr\/Charte-de-donnees-personnelles","purposeIds":["technical-data","audience-measurement"]},{"id":"facebook-pixel","name":"Facebook Pixel","policyUrl":"https:\/\/www.facebook.com\/business\/gdpr","purposeIds":["cookies"]},{"id":"atinternet","name":"AT-Internet","policyUrl":"https:\/\/www.atinternet.com\/rgpd-et-vie-privee\/","purposeIds":["audience-measurement","cookies"]}],"iab":{"all":false,"version":2,"include":[388,32]},"didomi":[]},"customPurposes":[{"id":"audience-measurement","name":{"en":"Audience measurement","fr":"Collecte de donn\u00e9es statistiques"},"description":{"en":"We collect statistical data to measure the audience of the application","fr":"Nous collectons des donn\u00e9es statistiques pour mesurer l'audience sur l'application."}},{"id":"technical-data","name":{"en":"Technical data","fr":"Donn\u00e9es techniques"},"description":{"en":"We process technical data which are necessary for service provision","fr":"Nous traitons vos donn\u00e9es pour une finalit\u00e9 technique et n\u00e9cessaire \u00e0 la d\u00e9livrance du service."}}],"essentialPurposes":["technical-data"]},"theme":{"linkColor":"#00bfff","buttons":{"highlightButtons":{"backgroundColor":"#333","textColor":"#fff","borderColor":"#333","borderWidth":"1px","borderRadius":"0px"}}}};
#             window.didomiOnReady = window.didomiOnReady || [];
#             window.didomiOnReady.push(function (Didomi) {
#                 if (!Didomi.notice.isVisible() && Didomi.isUserConsentStatusPartial()) {
#                     Didomi.preferences.show('vendors');
#                 }
#             });
#   </script>
#   <!-- END Didomi config -->
#   <!-- Didomi script -->
#   <script>
#    window.gdprAppliesGlobally = true;
#                 (function() {
#                     function a(e) {
#                         if (!window.frames[e]) {
#                             if (document.body && document.body.firstChild) {
#                                 var t = document.body;
#                                 var n = document.createElement('iframe');
#                                 n.style.display = 'none';
#                                 n.name = e;
#                                 n.title = e;
#                                 t.insertBefore(n, t.firstChild);
#                             } else {
#                                 setTimeout(function() {
#                                     a(e);
#                                 }, 5);
#                             }
#                         }
#                     }
#
#                     function e(n, r, o, c, s) {
#                         function e(e, t, n, a) {
#                             if (typeof n !== 'function') {
#                                 return;
#                             }
#                             if (!window[r]) {
#                                 window[r] = [];
#                             }
#                             var i = false;
#                             if (s) {
#                                 i = s(e, t, n);
#                             }
#                             if (!i) {
#                                 window[r].push({command: e, parameter: t, callback: n, version: a});
#                             }
#                         }
#
#                         e.stub = true;
#
#                         function t(a) {
#                             if (!window[n] || window[n].stub !== true) {
#                                 return;
#                             }
#                             if (!a.data) {
#                                 return;
#                             }
#                             var i = typeof a.data === 'string';
#                             var e;
#                             try {
#                                 e = i ? JSON.parse(a.data) : a.data;
#                             } catch (t) {
#                                 return;
#                             }
#                             if (e[o]) {
#                                 var r = e[o];
#                                 window[n](r.command, r.parameter, function(e, t) {
#                                     var n = {};
#                                     n[c] = {returnValue: e, success: t, callId: r.callId};
#                                     a.source.postMessage(i ? JSON.stringify(n) : n, '*');
#                                 }, r.version);
#                             }
#                         }
#
#                         if (typeof window[n] !== 'function') {
#                             window[n] = e;
#                             if (window.addEventListener) {
#                                 window.addEventListener('message', t, false);
#                             } else {
#                                 window.attachEvent('onmessage', t);
#                             }
#                         }
#                     }
#
#                     e('__tcfapi', '__tcfapiBuffer', '__tcfapiCall', '__tcfapiReturn');
#                     a('__tcfapiLocator');
#                     (function(e, tgt) {
#                         var t = document.createElement('script');
#                         t.id = 'spcloader';
#                         t.type = 'text/javascript';
#                         t.async = true;
#                         t.defer = true;
#                         t.src = 'https://sdk.privacy-center.org/' + e + '/loader.js?target_type=notice&target=' + tgt;
#                         t.charset = 'utf-8';
#                         var n = document.getElementsByTagName('script')[0];
#                         n.parentNode.insertBefore(t, n);
#                     })('27433fae-8ff9-4a87-a579-ccc8df989c27', 'm8qBjpNh');
#                 })();
#   </script>
#   <!-- END Didomi script -->
#   <script>
#    (function() {
#                     window.bridge.bootstrap('geoDivisions', {"globals":[],"components":{"critizr":{"active":true,"apiKey":"7f614697ac3524af3ca4ce0df9164caf"},"contactForm":{"funcs":["initModalConfig"],"recaptcha":{"active":"${CONTACT_FORM_RECAPTCHA_ACTIVE}","container":"contact-captcha-container","siteKey":"6LffusEdAAAAANsaKqoo8uy93KIC0Q84BvJNHfJA"}},"newsletterForm":{"funcs":["initModalConfig"],"recaptcha":{"active":"${CONTACT_FORM_RECAPTCHA_ACTIVE}","container":"newsletter-captcha-container","siteKey":"6LffusEdAAAAANsaKqoo8uy93KIC0Q84BvJNHfJA"}},"addressForm":{"funcs":["definePhoneValidation","initModalConfig"],"recaptcha":{"active":"${CONTACT_FORM_RECAPTCHA_ACTIVE}","container":"address-captcha-container","siteKey":"6LffusEdAAAAANsaKqoo8uy93KIC0Q84BvJNHfJA"}},"geolocation":{"useGeocoding":true,"searchUrlTemplate":"\/search"},"tracking":{"keys":{"fr":{"bridge":"629632","client":"GTM-MB8MXZ"},"en":{"bridge":"629632","client":""},"en_CA":{"bridge":"629632","client":"GTM-53CCMTW"},"es":{"bridge":"629632","client":"GTM-57JB3NX"},"fr_CA":{"bridge":"629632","client":"GTM-5ML487M"},"he":{"bridge":"629632","client":"GTM-NMRN8QG"},"nl":{"bridge":"629632","client":"GTM-WV9W4L3"}},"didomiConfig":{"fr":{"enable":true,"requireScript":true,"requireConfig":true,"keys":{"apiKey":"27433fae-8ff9-4a87-a579-ccc8df989c27","noticeId":"m8qBjpNh"},"vendorIds":{"bridge":"c:bridge","googleAnalytics":"c:googleanalytics","atInternet":"c:atinternet","facebook":"didomi:facebook","twitter":"didomi:twitter","youtube":"c:youtube","snapwidget":"c:snapwidget","effilab":"c:effilab","tracking-numberly":"iab:388"},"config":{"app":{"vendors":{"iab":{"all":false,"version":2,"include":[388,32]},"didomi":[],"custom":[{"id":"facebook-pixel","name":"Facebook Pixel","policyUrl":"https:\/\/www.facebook.com\/business\/gdpr","purposeIds":["cookies"]}]}},"theme":{"linkColor":"#00bfff","buttons":{"highlightButtons":{"backgroundColor":"#333","textColor":"#fff","borderColor":"#333","borderWidth":"1px","borderRadius":"0px"}}}}},"en":{"enable":true,"requireScript":true,"requireConfig":true,"keys":{"apiKey":"27433fae-8ff9-4a87-a579-ccc8df989c27","noticeId":"m8qBjpNh"},"vendorIds":{"bridge":"c:bridge","googleAnalytics":"c:googleanalytics","atInternet":"c:atinternet","facebook":"didomi:facebook","twitter":"didomi:twitter","youtube":"c:youtube","snapwidget":"c:snapwidget","effilab":"c:effilab","tracking-numberly":"iab:388"},"config":{"app":{"vendors":{"iab":{"all":false,"version":2,"include":[388,32]},"didomi":[],"custom":[{"id":"facebook-pixel","name":"Facebook Pixel","policyUrl":"https:\/\/www.facebook.com\/business\/gdpr","purposeIds":["cookies"]}]}},"theme":{"linkColor":"#00bfff","buttons":{"highlightButtons":{"backgroundColor":"#333","textColor":"#fff","borderColor":"#333","borderWidth":"1px","borderRadius":"0px"}}}}},"en_CA":{"enable":false,"requireScript":true,"requireConfig":true,"keys":{"apiKey":"27433fae-8ff9-4a87-a579-ccc8df989c27","noticeId":"m8qBjpNh"},"vendorIds":{"bridge":"c:bridge","googleAnalytics":"c:googleanalytics","atInternet":"c:atinternet","facebook":"didomi:facebook","twitter":"didomi:twitter","youtube":"c:youtube","snapwidget":"c:snapwidget","effilab":"c:effilab","tracking-numberly":"iab:388"},"config":{"app":{"vendors":{"iab":{"all":false,"version":2,"include":[388,32]},"didomi":[],"custom":[]}},"theme":{"linkColor":"#00bfff","buttons":{"highlightButtons":{"backgroundColor":"#333","textColor":"#fff","borderColor":"#333","borderWidth":"1px","borderRadius":"0px"}}}}},"es":{"enable":true,"requireScript":true,"requireConfig":true,"keys":{"apiKey":"27433fae-8ff9-4a87-a579-ccc8df989c27","noticeId":"m8qBjpNh"},"vendorIds":{"bridge":"c:bridge","googleAnalytics":"c:googleanalytics","atInternet":"c:atinternet","facebook":"didomi:facebook","twitter":"didomi:twitter","youtube":"c:youtube","snapwidget":"c:snapwidget","effilab":"c:effilab","tracking-numberly":"iab:388"},"config":{"app":{"vendors":{"iab":{"all":false,"version":2,"include":[388,32]},"didomi":[],"custom":[ ...
#                 })()
#   </script>
#  </body>
# </html>

# %%
def address_from_tag(address_tags):
    try:
        tags = address_tags.find_all('div')
        address_components = [elem.contents[0].replace(u'\xa0', u' ').strip(' ') for elem in tags[1:]]
        address = ' '.join(address_components)
    except:
        address = np.nan
    return address

# %%
main_link_pre = 'https://audition.optical-center.fr/fr?page='
df_list = []

for i in range(1, 36):
    
    if (i%5==0):
        print(f'Scraping page {i}/35...')

    main_link = main_link_pre + str(i)
    page = urllib3.PoolManager().request('GET', main_link)
    soup = BeautifulSoup(page.data, features="html.parser")

    tags = soup.find_all('div', {'class':"lf-location-default__content__main__container lf-geo-divisions__main__locations__list__location__content__main__container"})
    names = []
    addresses = []
    for tag in tags:
        names.append(tag.find('h2').find('span').contents[0])
        addresses.append(address_from_tag(tag.find('address', {'class':"lf-parts-address lf-location-default__content__main__container__address lf-geo-divisions__main__locations__list__location__content__container__address"})))

    df_list.append(pd.DataFrame({'shop_name': names, 'address': addresses}))

df = pd.concat(df_list)
# Out:
# Scraping page 5/35...
# Scraping page 10/35...
# Scraping page 15/35...
# Scraping page 20/35...
# Scraping page 25/35...
# Scraping page 30/35...
# Scraping page 35/35...

# %%
mask = df['shop_name'].str.startswith('Audioprothésiste')
df = df[mask].reset_index(drop=True)
df.head()
# Out:
#                                            shop_name  \
# 0            Audioprothésiste CHAMANT Optical Center
# 1      Audioprothésiste CHÂTEAURENARD Optical Center
# 2            Audioprothésiste AUBIÈRE Optical Center
# 3             Audioprothésiste DRANCY Optical Center
# 4  Audioprothésiste  DINARD - PLEURTUIT Optical C...
#
#                                              address
# 0                  6, Avenue du Poteau 60300 Chamant
# 1  698, Boulevard Ernest Genevet 13160 Chateaurenard
# 2                127 Avenue de Cournon 63170 Aubière
# 3            140, Avenue Henri Barbusse 93700 Drancy
# 4         ZAC de la Ville Es Meniers 35730 Pleurtuit

# %%
# geolocate shops
geolocator = IGNFrance()

df['latitude'] = np.nan
df['longitude'] = np.nan
df['city'] = np.nan
df['postcode'] = np.nan

for i in df.index:

    if ((i>0) and (i%50==0)):
        print(f'{i}/{len(df)}')

    try:
        #tries fetch address from geopy
        location = geolocator.geocode(df['address'][i], timeout=None)
        
        #append lat/long to column using dataframe location
        df.loc[i,'latitude'] = float(location.latitude)
        df.loc[i,'longitude'] = float(location.longitude)
        df.loc[i,'city'] = location.raw['commune']
        df.loc[i,'postcode'] = location.raw['postal_code']
        
    except:
        continue
# Out:
# 50/596
# 100/596
# 150/596
# 200/596
# 250/596
# 300/596
# 350/596
# 400/596
# 450/596
# 500/596
# 550/596

# %%
# check
df.head()
# Out:
#                                            shop_name  \
# 0            Audioprothésiste CHAMANT Optical Center
# 1      Audioprothésiste CHÂTEAURENARD Optical Center
# 2            Audioprothésiste AUBIÈRE Optical Center
# 3             Audioprothésiste DRANCY Optical Center
# 4  Audioprothésiste  DINARD - PLEURTUIT Optical C...
#
#                                              address   latitude  longitude  \
# 0                  6, Avenue du Poteau 60300 Chamant  49.216698   2.595482
# 1  698, Boulevard Ernest Genevet 13160 Chateaurenard  43.887916   4.853680
# 2                127 Avenue de Cournon 63170 Aubière  45.755981   3.149182
# 3            140, Avenue Henri Barbusse 93700 Drancy  48.920326   2.452644
# 4         ZAC de la Ville Es Meniers 35730 Pleurtuit  48.614237  -2.060204
#
#             city postcode
# 0        Chamant    60300
# 1  Châteaurenard    13160
# 2        Aubière    63170
# 3         Drancy    93700
# 4      Pleurtuit    35730

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596 entries, 0 to 595
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  596 non-null    object
#  1   address    596 non-null    object
#  2   latitude   596 non-null    float64
#  3   longitude  596 non-null    float64
#  4   city       596 non-null    object
#  5   postcode   596 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 28.1+ KB

# %%
df.to_csv('../output/opticalcenter_shops_geocoded.csv', index=False)
