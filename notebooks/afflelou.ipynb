# %%
import urllib3
from bs4 import BeautifulSoup
from itertools import compress
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim, IGNFrance, BANFrance

# %%
page = urllib3.PoolManager().request('GET', 'https://www.alainafflelou-acousticien.fr/audioprothesiste/france')
soup = BeautifulSoup(page.data, features="html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="c-page js-page c-page--userDisconnected" lang="fr">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Audioprothésistes ALAIN AFFLELOU Acousticien France
#   </title>
#   <meta content="    Vous recherchez un Opticien AFFLELOU en france ? Localisez l\'Opticien Afflelou le plus proche avec ses horaires, ses coordonnées et toutes ses infos pratiques.
# " name="description"/>
#   <link href="https://www.alainafflelou-acousticien.fr/audioprothesiste/france" rel="canonical"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Alain Afflelou Acousticien" property="og:title"/>
#   <meta content="https://www.alainafflelou-acousticien.fr/img/social/aaa-share.jpg" property="og:image"/>
#   <link href="/main.18ed2c6f.css" rel="stylesheet"/>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,600;0,700;0,800;1,300;1,400;1,600;1,700&amp;display=swap" rel="stylesheet"/>
#   <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <script type="text/javascript">
#    window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
#                 else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
#                     var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
#                     if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#                     var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target="+document.location.hostname;t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})("f8cdc11e-df31-47f5-bafd-f437ffdc5c41")})();
#   </script>
#   <script type="text/javascript">
#    /*<![CDATA[*/
#                                     var dataLayer = [];
#                                 /*]]>*/
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window,document,'script','dataLayer', 'GTM-KCN4GJ');
#   </script>
#   <!-- End Google Tag Manager -->
#  </head>
#  <body class="has-navbar-fixed" id="main">
#   <span data-component="query-params" data-expirehours="24" data-method="addToStorage" data-params="codemedia,utm_source,utm_medium,utm_campaign,utm_term,utm_content,utm_channel,gclid">
#   </span>
#   <div id="divDataLayerInit">
#    <input data-component="datalayer-init" data-elements='{"pageUrl":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france","pageType":null,"pageCategory":null,"userId":"","login_status":"unlogged","email":"","userGender":"","userTitle":"","userAge":"","userPostalCode":"","userCustomer":2,"siteLang":"fr_FR","siteType":"d","pageAdwordsCategory":"","environment":"prod","orderNumber":null,"customerType":null,"subscription":null}' id="dataLayerInit" type="hidden"/>
#   </div>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KCN4GJ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <header data-component="menu-collapse" id="header">
#    <div class="container container--large h-100">
#     <div class="c-header-aacoustic">
#      <a class="c-header-aacoustic__logo" data-elements='{"event":"GAevent","category":"AAA_logo","action":"back_to_HP","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/">
#       <img alt="Alain Afflelou Acousticien" src="/img/logo_aaa.svg"/>
#      </a>
#      <div class="c-header-aacoustic__right">
#       <div class="c-header-aacoustic__menu-top">
#        <ul class="menu d-none d-md-flex">
#         <li class="menu-item">
#          <a class="menu-link menu-link-primary" data-elements='{"event":"GAevent","category":"header","action":"click_store_locator","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/audioprothesiste">
#           <span class="svgbox">
#            <svg viewbox="0 0 15.4 22" xmlns="http://www.w3.org/2000/svg">
#             <path d="M11,22l-.4-.4-.8-1A42.2,42.2,0,0,1,7.1,17a27.6,27.6,0,0,1-2.6-4.6A12,12,0,0,1,3.3,7.7,7.8,7.8,0,0,1,11,0a7.8,7.8,0,0,1,7.7,7.7,12,12,0,0,1-1.2,4.7A22.8,22.8,0,0,1,14.8,17a27,27,0,0,1-2.6,3.6l-.8,1ZM11,1A6.7,6.7,0,0,0,4.3,7.7,11.8,11.8,0,0,0,5.4,12,38.4,38.4,0,0,0,8,16.5a38.5,38.5,0,0,0,2.6,3.4l.4.6.4-.6A32.2,32.2,0,0,0,14,16.5,38.4,38.4,0,0,0,16.6,12a11.8,11.8,0,0,0,1.1-4.3A6.7,6.7,0,0,0,11,1Z" transform="translate(-3.3)">
#             </path>
#             <circle cx="7.7" cy="7.7" r="2.8">
#             </circle>
#            </svg>
#           </span>
#           Trouver un centre
#          </a>
#         </li>
#         <li class="menu-item">
#          <a class="menu-link menu-link-primary" data-elements='{"event":"GAevent","category":"header","action":"click_appointment","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/rendez-vous/trouver-centre-acousticien">
#           <span class="svgbox">
#            <svg viewbox="0 0 16.5 17.88" xmlns="http://www.w3.org/2000/svg">
#             <path d="M19.3,4.94a1.84,1.84,0,0,0-1.69-1.09h-.92V2.06H14.86V3.85H7.53V2.06H5.69V3.85H4.78a1.83,1.83,0,0,0-1.52.79,1.73,1.73,0,0,0-.32,1V18.15a1.82,1.82,0,0,0,1.84,1.79H17.61a1.81,1.81,0,0,0,1.83-1.79V5.64A1.82,1.82,0,0,0,19.3,4.94Zm-.86,13.21a.82.82,0,0,1-.83.79H4.78a.82.82,0,0,1-.84-.79V8.22h14.5Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M7.53,10.89a.92.92,0,1,0-.92.9A.91.91,0,0,0,7.53,10.89Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M5.69,16.26a.92.92,0,1,0,.92-.9A.91.91,0,0,0,5.69,16.26Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M5.69,13.57a.92.92,0,1,0,.92-.89A.91.91,0,0,0,5.69,13.57Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M10.28,16.26a.92.92,0,1,0,.91-.9A.9.9,0,0,0,10.28,16.26Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M10.28,13.57a.92.92,0,1,0,.91-.89A.9.9,0,0,0,10.28,13.57Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M10.28,10.89a.92.92,0,1,0,.91-.89A.9.9,0,0,0,10.28,10.89Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M14.86,16.26a.92.92,0,1,0,.92-.9A.91.91,0,0,0,14.86,16.26Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M15.78,12.68a.9.9,0,1,0,.91.89A.91.91,0,0,0,15.78,12.68Z" transform="translate(-2.94 -2.06)">
#             </path>
#             <path d="M14.86,10.89a.92.92,0,1,0,.92-.89A.91.91,0,0,0,14.86,10.89Z" transform="translate(-2.94 -2.06)">
#             </path>
#            </svg>
#           </span>
#           Prendre rendez-vous
#          </a>
#         </li>
#         <li class="menu-item">
#          <a class="menu-link menu-link-primary" data-elements='{"event":"GAevent","category":"header","action":"click_hearing_test","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/audition/test-audition/test-auditif-gratuit-ligne">
#           <span class="svgbox">
#            <svg viewbox="0 0 19.4 20.5" xmlns="http://www.w3.org/2000/svg">
#             <path d="M1.7,7.9H.7A8.1,8.1,0,0,1,3.6,2.1,8.1,8.1,0,0,1,9.2,0h.5V1H9.2a8.3,8.3,0,0,0-5,1.8A7.6,7.6,0,0,0,1.7,7.9Z" transform="translate(-0.7)">
#             </path>
#             <path d="M12.2,20.5a4.1,4.1,0,0,1-1.6-.3A5.2,5.2,0,0,1,8,16.8c-.2-.7-.6-1-1.3-1.5a9,9,0,0,1-2.6-2.8A7.9,7.9,0,0,1,3.2,9,6.4,6.4,0,0,1,9.7,2.5a6.4,6.4,0,0,1,6.2,4.7l-1,.3a5.3,5.3,0,0,0-5.2-4A5.4,5.4,0,0,0,4.2,9,7.1,7.1,0,0,0,5,12a7.1,7.1,0,0,0,2.3,2.5,4.8,4.8,0,0,1,1.7,2,3.9,3.9,0,0,0,2.1,2.8l1.1.2a2.9,2.9,0,0,0,3-2.9V13.1h1v3.5A3.9,3.9,0,0,1,12.2,20.5Z" transform="translate(-0.7)">
#             </path>
#             <polygon points="11.7 14.5 7.2 10 8.5 8.8 11.7 12 18.2 5.6 19.4 6.8 11.7 14.5">
#             </polygon>
#            </svg>
#           </span>
#           Test auditif
#          </a>
#         </li>
#        </ul>
#        <div class="c-header-aacoustic__actions">
#         <a class="action" data-elements='{"event":"GAevent","category":"header","action":"click_contact","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="/contactez-nous">
#          <img alt="Contact" class="action-icon" src="/img/icons/icon_callback-2.svg"/>
#         </a>
#         <a class="action" data-elements='{"event":"GAevent","category":"header","action":"click_account","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="/identification-inscription">
#          <img alt="Mon Compte" class="action-icon" src="/img/icons/icon_account.svg"/>
#         </a>
#         <a class="action" href="javascript:void(0);" id="switch-size">
#          <img alt="Zoomer/Dézoomer" class="action-icon" src="/img/icons/icon_switch-size.svg"/>
#         </a>
#         <a class="action d-xs-flex d-lg-none" href="javascript:void(0);" id="menu-sm">
#          <img alt="Menu" class="menu-icon" src="/img/icons/icon_burger.svg"/>
#         </a>
#        </div>
#       </div>
#       <nav class="c-header-aacoustic__navigation has-md-collapse bordered">
#        <button class="btn-close" id="close-menu">
#         <img alt="" src="/img/icons/icon_close.svg"/>
#        </button>
#        <ul class="navigation-menu" id="menu">
#         <li class="d-block d-md-none">
#          <div class="c-header-aacoustic__menu-top">
#           <ul class="menu">
#            <li class="menu-item">
#             <a class="menu-link" data-elements='{"event":"GAevent","category":"header","action":"click_store_locator","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/audioprothesiste">
#              <span class="svgbox">
#               <svg viewbox="0 0 15.4 22" xmlns="http://www.w3.org/2000/svg">
#                <path d="M11,22l-.4-.4-.8-1A42.2,42.2,0,0,1,7.1,17a27.6,27.6,0,0,1-2.6-4.6A12,12,0,0,1,3.3,7.7,7.8,7.8,0,0,1,11,0a7.8,7.8,0,0,1,7.7,7.7,12,12,0,0,1-1.2,4.7A22.8,22.8,0,0,1,14.8,17a27,27,0,0,1-2.6,3.6l-.8,1ZM11,1A6.7,6.7,0,0,0,4.3,7.7,11.8,11.8,0,0,0,5.4,12,38.4,38.4,0,0,0,8,16.5a38.5,38.5,0,0,0,2.6,3.4l.4.6.4-.6A32.2,32.2,0,0,0,14,16.5,38.4,38.4,0,0,0,16.6,12a11.8,11.8,0,0,0,1.1-4.3A6.7,6.7,0,0,0,11,1Z" transform="translate(-3.3)">
#                </path>
#                <circle cx="7.7" cy="7.7" r="2.8">
#                </circle>
#               </svg>
#              </span>
#              Trouver un centre
#             </a>
#            </li>
#            <li class="menu-item">
#             <a class="menu-link" data-elements='{"event":"GAevent","category":"header","action":"click_appointment","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/rendez-vous/trouver-centre-acousticien">
#              <span class="svgbox">
#               <svg viewbox="0 0 16.5 17.88" xmlns="http://www.w3.org/2000/svg">
#                <path d="M19.3,4.94a1.84,1.84,0,0,0-1.69-1.09h-.92V2.06H14.86V3.85H7.53V2.06H5.69V3.85H4.78a1.83,1.83,0,0,0-1.52.79,1.73,1.73,0,0,0-.32,1V18.15a1.82,1.82,0,0,0,1.84,1.79H17.61a1.81,1.81,0,0,0,1.83-1.79V5.64A1.82,1.82,0,0,0,19.3,4.94Zm-.86,13.21a.82.82,0,0,1-.83.79H4.78a.82.82,0,0,1-.84-.79V8.22h14.5Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M7.53,10.89a.92.92,0,1,0-.92.9A.91.91,0,0,0,7.53,10.89Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M5.69,16.26a.92.92,0,1,0,.92-.9A.91.91,0,0,0,5.69,16.26Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M5.69,13.57a.92.92,0,1,0,.92-.89A.91.91,0,0,0,5.69,13.57Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M10.28,16.26a.92.92,0,1,0,.91-.9A.9.9,0,0,0,10.28,16.26Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M10.28,13.57a.92.92,0,1,0,.91-.89A.9.9,0,0,0,10.28,13.57Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M10.28,10.89a.92.92,0,1,0,.91-.89A.9.9,0,0,0,10.28,10.89Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M14.86,16.26a.92.92,0,1,0,.92-.9A.91.91,0,0,0,14.86,16.26Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M15.78,12.68a.9.9,0,1,0,.91.89A.91.91,0,0,0,15.78,12.68Z" transform="translate(-2.94 -2.06)">
#                </path>
#                <path d="M14.86,10.89a.92.92,0,1,0,.92-.89A.91.91,0,0,0,14.86,10.89Z" transform="translate(-2.94 -2.06)">
#                </path>
#               </svg>
#              </span>
#              Prendre rendez-vous
#             </a>
#            </li>
#            <li class="menu-item">
#             <a class="menu-link" data-elements='{"event":"GAevent","category":"header","action":"click_hearing_test","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/audition/test-audition/test-auditif-gratuit-ligne">
#              <span class="svgbox">
#               <svg viewbox="0 0 19.4 20.5" xmlns="http://www.w3.org/2000/svg">
#                <path d="M1.7,7.9H.7A8.1,8.1,0,0,1,3.6,2.1,8.1,8.1,0,0,1,9.2,0h.5V1H9.2a8.3,8.3,0,0,0-5,1.8A7.6,7.6,0,0,0,1.7,7.9Z" transform="translate(-0.7)">
#                </path>
#                <path d="M12.2,20.5a4.1,4.1,0,0,1-1.6-.3A5.2,5.2,0,0,1,8,16.8c-.2-.7-.6-1-1.3-1.5a9,9,0,0,1-2.6-2.8A7.9,7.9,0,0,1,3.2,9,6.4,6.4,0,0,1,9.7,2.5a6.4,6.4,0,0,1,6.2,4.7l-1,.3a5.3,5.3,0,0,0-5.2-4A5.4,5.4,0,0,0,4.2,9,7.1,7.1,0,0,0,5,12a7.1,7.1,0,0,0,2.3,2.5,4.8,4.8,0,0,1,1.7,2,3.9,3.9,0,0,0,2.1,2.8l1.1.2a2.9,2.9,0,0,0,3-2.9V13.1h1v3.5A3.9,3.9,0,0,1,12.2,20.5Z" transform="translate(-0.7)">
#                </path>
#                <polygon points="11.7 14.5 7.2 10 8.5 8.8 11.7 12 18.2 5.6 19.4 6.8 11.7 14.5">
#                </polygon>
#               </svg>
#              </span>
#              Test auditif
#             </a>
#            </li>
#           </ul>
#          </div>
#         </li>
#         <li class="menu-item">
#          <div class="d-flex">
#           <a class="menu-link menu-link--dropdown" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_menu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;L'audition&quot;}" data-role="datalayer-push-click" href="/audition">
#            L'audition
#            <span class="menu-link__arrow">
#            </span>
#           </a>
#           <button aria-controls="collapse" aria-expanded="true" class="c-btn-toggle d-flex d-lg-none p-4 bg-white h-100 collapsed" data-bs-target="#menu15" data-bs-toggle="collapse" type="button">
#            <span class="c-icon c-icon--toggle c-icon--sm c-icon--primary svgbox">
#             <svg viewbox="0 0 25.06 13.88" xmlns="http://www.w3.org/2000/svg">
#              <path d="M25.06,1.61c0,.38-.15,.77-.44,1.06L14,13.29c-.78,.78-2.05,.78-2.83,0L.44,2.56C-.15,1.97-.15,1.03,.44,.44,1.02-.15,1.98-.15,2.56,.44L12.59,10.46,22.42,.63c.57-.57,1.5-.68,2.11-.16,.35,.3,.53,.72,.53,1.15Z">
#              </path>
#             </svg>
#            </span>
#           </button>
#          </div>
#          <div class="c-header-aacoustic__submenu">
#           <div class="submenu-wrapper">
#            <div class="container pe-0">
#             <div class="collapse w-100" data-bs-parent="#menu" id="menu15">
#              <div class="row w-100">
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_intermediary_menu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;Tout savoir sur l'audition&quot;}" data-role="datalayer-push-click" href="/audition/tout-savoir-audition">
#                  Tout savoir sur l'audition
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Oreille et audition : comment \u00e7a marche ?"}' data-role="datalayer-push-click" href="/audition/tout-savoir-audition/oreille-audition">
#                   Oreille et audition : comment ça marche ?
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_submenu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;Reconnaitre une baisse d'audition&quot;}" data-role="datalayer-push-click" href="/audition/tout-savoir-audition/reconnaitre-baisse-audition">
#                   Reconnaitre une baisse d'audition
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Les trois types de pertes auditives"}' data-role="datalayer-push-click" href="/audition/tout-savoir-audition/types-pertes-auditives">
#                   Les trois types de pertes auditives
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Comment prot\u00e9ger son audition ?"}' data-role="datalayer-push-click" href="/audition/tout-savoir-audition/comment-proteger-audition">
#                   Comment protéger son audition ?
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Les troubles auditifs"}' data-role="datalayer-push-click" href="/audition/troubles-auditifs">
#                  Les troubles auditifs
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"La presbyacousie"}' data-role="datalayer-push-click" href="/audition/troubles-auditifs/presbyacousie">
#                   La presbyacousie
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"L\u2019hyperacousie et l\u2019hypoacousie"}' data-role="datalayer-push-click" href="/audition/troubles-auditifs/hypoacousie-hyperacousie">
#                   L’hyperacousie et l’hypoacousie
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Les acouph\u00e8nes"}' data-role="datalayer-push-click" href="/audition/troubles-auditifs/acouphenes">
#                   Les acouphènes
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"La maladie de M\u00e9ni\u00e8re"}' data-role="datalayer-push-click" href="/audition/troubles-auditifs/maladie-meniere">
#                   La maladie de Ménière
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_submenu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;L'otospongiose&quot;}" data-role="datalayer-push-click" href="/audition/troubles-auditifs/otospongiose">
#                   L'otospongiose
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Comment traiter une perte auditive"}' data-role="datalayer-push-click" href="/audition/traiter-perte-auditive">
#                  Comment traiter une perte auditive
#                 </a>
#                </li>
#               </ul>
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Testez votre audition"}' data-role="datalayer-push-click" href="/audition/test-audition">
#                  Testez votre audition
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Bilan auditif chez un m\u00e9decin ORL"}' data-role="datalayer-push-click" href="/audition/test-audition/bilan-auditif-medecin-orl">
#                   Bilan auditif chez un médecin ORL
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Test auditif gratuit en centre"}' data-role="datalayer-push-click" href="/audition/test-audition/test-auditif-gratuit-centre">
#                   Test auditif gratuit en centre
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Test auditif gratuit en ligne"}' data-role="datalayer-push-click" href="/audition/test-audition/test-auditif-gratuit-ligne">
#                   Test auditif gratuit en ligne
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <div class="rdv-block">
#                <div class="border-start border-3 border-primary">
#                 <img alt="" src="/img/header/essai-gratuit-sous-menu.jpg"/>
#                </div>
#                <div>
#                 <span class="c-title c-title--primary c-title--primary-sm d-block">
#                  1 Mois d'essai
#                  <br/>
#                  gratuit !
#                 </span>
#                 <a class="btn btn-primary mt-1" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_appointment","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/rendez-vous/trouver-centre-acousticien">
#                  Prendre rendez-vous
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="menu-item">
#          <div class="d-flex">
#           <a class="menu-link menu-link--dropdown" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_menu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;L'expertise ALAIN AFFLELOU&quot;}" data-role="datalayer-push-click" href="/expertise">
#            L'expertise ALAIN AFFLELOU
#            <span class="menu-link__arrow">
#            </span>
#           </a>
#           <button aria-controls="collapse" aria-expanded="true" class="c-btn-toggle d-flex d-lg-none p-4 bg-white h-100 collapsed" data-bs-target="#menu16" data-bs-toggle="collapse" type="button">
#            <span class="c-icon c-icon--toggle c-icon--sm c-icon--primary svgbox">
#             <svg viewbox="0 0 25.06 13.88" xmlns="http://www.w3.org/2000/svg">
#              <path d="M25.06,1.61c0,.38-.15,.77-.44,1.06L14,13.29c-.78,.78-2.05,.78-2.83,0L.44,2.56C-.15,1.97-.15,1.03,.44,.44,1.02-.15,1.98-.15,2.56,.44L12.59,10.46,22.42,.63c.57-.57,1.5-.68,2.11-.16,.35,.3,.53,.72,.53,1.15Z">
#              </path>
#             </svg>
#            </span>
#           </button>
#          </div>
#          <div class="c-header-aacoustic__submenu">
#           <div class="submenu-wrapper">
#            <div class="container pe-0">
#             <div class="collapse w-100" data-bs-parent="#menu" id="menu16">
#              <div class="row w-100">
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Notre accompagnement"}' data-role="datalayer-push-click" href="/expertise/accompagnement">
#                  Notre accompagnement
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Essai 30 jours gratuit"}' data-role="datalayer-push-click" href="/expertise/accompagnement/essai-30-jours-gratuit">
#                   Essai 30 jours gratuit
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_submenu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;Suivi d'appareillage illimit\u00e9&quot;}" data-role="datalayer-push-click" href="/expertise/accompagnement/suivi-appareillage-illimite">
#                   Suivi d'appareillage illimité
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Renouvellement des appareils auditifs"}' data-role="datalayer-push-click" href="/expertise/accompagnement/renouvellement-appareils-auditifs">
#                   Renouvellement des appareils auditifs
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Les engagements ALAIN AFFLELOU Acousticien"}' data-role="datalayer-push-click" href="/expertise/accompagnement/engagements">
#                   Les engagements ALAIN AFFLELOU Acousticien
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Entretien de vos aides auditives"}' data-role="datalayer-push-click" href="/expertise/accompagnement/entretien-aides-auditives">
#                   Entretien de vos aides auditives
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Notre r\u00e9seau"}' data-role="datalayer-push-click" href="/expertise/reseau">
#                  Notre réseau
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_submenu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;Les cabines d'audiologie ALAIN AFFLELOU Acousticien&quot;}" data-role="datalayer-push-click" href="/expertise/reseau/cabines-audiologie">
#                   Les cabines d'audiologie ALAIN AFFLELOU Acousticien
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Les \u00e9quipes ALAIN AFFLELOU Acousticien"}' data-role="datalayer-push-click" href="/expertise/reseau/equipes">
#                   Les équipes ALAIN AFFLELOU Acousticien
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Les centres ALAIN AFFLELOU Acousticien"}' data-role="datalayer-push-click" href="/expertise/reseau/centres">
#                   Les centres ALAIN AFFLELOU Acousticien
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Nos offres"}' data-role="datalayer-push-click" href="/expertise/offres">
#                  Nos offres
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Tchin Tchin Audio"}' data-role="datalayer-push-click" href="/expertise/offres/tchin-tchin-audio">
#                   Tchin Tchin Audio
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Offre Crois\u00e9e : bien entendre et bien voir"}' data-role="datalayer-push-click" href="/expertise/offres/offre-croisee">
#                   Offre Croisée : bien entendre et bien voir
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Service voituriers \u00e0 domicile"}' data-role="datalayer-push-click" href="/expertise/offres#service-voituriers">
#                   Service voituriers à domicile
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Prix et financements"}' data-role="datalayer-push-click" href="/expertise/prix-financements">
#                  Prix et financements
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Prix et remboursement des aides auditives"}' data-role="datalayer-push-click" href="/expertise/prix-financements/prix-remboursement-aides-auditives">
#                   Prix et remboursement des aides auditives
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Next Year, le financement by Afflelou"}' data-role="datalayer-push-click" href="/expertise/prix-financements/next-year-financement-afflelou">
#                   Next Year, le financement by Afflelou
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Mutuelles et 100% sant\u00e9"}' data-role="datalayer-push-click" href="/expertise/prix-financements/mutuelles-100-pourcent-sante">
#                   Mutuelles et 100% santé
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <div class="rdv-block">
#                <div class="border-start border-3 border-primary">
#                 <img alt="" src="/img/header/essai-gratuit-sous-menu.jpg"/>
#                </div>
#                <div>
#                 <span class="c-title c-title--primary c-title--primary-sm d-block">
#                  1 Mois d'essai
#                  <br/>
#                  gratuit !
#                 </span>
#                 <a class="btn btn-primary mt-1" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_appointment","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/rendez-vous/trouver-centre-acousticien">
#                  Prendre rendez-vous
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="menu-item">
#          <div class="d-flex">
#           <a class="menu-link menu-link--dropdown" data-elements='{"event":"GAevent","category":"header_menu","action":"click_header","label":"Appareils auditifs"}' data-role="datalayer-push-click" href="/appareils-auditifs">
#            Appareils auditifs
#            <span class="menu-link__arrow">
#            </span>
#           </a>
#           <button aria-controls="collapse" aria-expanded="true" class="c-btn-toggle d-flex d-lg-none p-4 bg-white h-100 collapsed" data-bs-target="#menu17" data-bs-toggle="collapse" type="button">
#            <span class="c-icon c-icon--toggle c-icon--sm c-icon--primary svgbox">
#             <svg viewbox="0 0 25.06 13.88" xmlns="http://www.w3.org/2000/svg">
#              <path d="M25.06,1.61c0,.38-.15,.77-.44,1.06L14,13.29c-.78,.78-2.05,.78-2.83,0L.44,2.56C-.15,1.97-.15,1.03,.44,.44,1.02-.15,1.98-.15,2.56,.44L12.59,10.46,22.42,.63c.57-.57,1.5-.68,2.11-.16,.35,.3,.53,.72,.53,1.15Z">
#              </path>
#             </svg>
#            </span>
#           </button>
#          </div>
#          <div class="c-header-aacoustic__submenu">
#           <div class="submenu-wrapper">
#            <div class="container pe-0">
#             <div class="collapse w-100" data-bs-parent="#menu" id="menu17">
#              <div class="row w-100">
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Les formes"}' data-role="datalayer-push-click" href="/appareils-auditifs/formes">
#                  Les formes
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Appareils auditifs intra-auriculaires"}' data-role="datalayer-push-click" href="/appareils-auditifs/formes/intra-auriculaires">
#                   Appareils auditifs intra-auriculaires
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_submenu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;Aides auditives mini-contours d'oreilles&quot;}" data-role="datalayer-push-click" href="/appareils-auditifs/formes/mini-contours-oreilles">
#                   Aides auditives mini-contours d'oreilles
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_submenu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;Appareils auditifs contours d'oreilles&quot;}" data-role="datalayer-push-click" href="/appareils-auditifs/formes/contours-oreilles">
#                   Appareils auditifs contours d'oreilles
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements='{"event":"GAevent","category":"header_intermediary_menu","action":"click_header","label":"Les technologies"}' data-role="datalayer-push-click" href="/appareils-auditifs/technologies">
#                  Les technologies
#                 </a>
#                </li>
#                <ul class="submenu-block">
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Appareils auditifs connect\u00e9s"}' data-role="datalayer-push-click" href="/appareils-auditifs/technologies/connectes">
#                   Appareils auditifs connectés
#                  </a>
#                 </li>
#                 <li>
#                  <a class="submenu-link" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_header","label":"Appareils auditifs rechargeables"}' data-role="datalayer-push-click" href="/appareils-auditifs/technologies/rechargeables">
#                   Appareils auditifs rechargeables
#                  </a>
#                 </li>
#                </ul>
#               </ul>
#               <ul class="col">
#                <li>
#                 <a class="submenu-link-primary" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_intermediary_menu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;Notre catalogue d'appareils auditifs&quot;}" data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/appareils-auditifs/notre-catalogue/">
#                  Notre catalogue d'appareils auditifs
#                 </a>
#                </li>
#               </ul>
#               <div class="rdv-block">
#                <div class="border-start border-3 border-primary">
#                 <img alt="" src="/img/header/essai-gratuit-sous-menu.jpg"/>
#                </div>
#                <div>
#                 <span class="c-title c-title--primary c-title--primary-sm d-block">
#                  1 Mois d'essai
#                  <br/>
#                  gratuit !
#                 </span>
#                 <a class="btn btn-primary mt-1" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_appointment","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="https://www.alainafflelou-acousticien.fr/rendez-vous/trouver-centre-acousticien">
#                  Prendre rendez-vous
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="menu-item">
#          <div class="d-flex">
#           <a class="menu-link menu-link--dropdown" href="https://www.afflelou.com/audiologie/" target="_blank">
#            Achetez vos accessoires
#            <span class="menu-link__arrow">
#            </span>
#           </a>
#           <button aria-controls="collapse" aria-expanded="true" class="c-btn-toggle d-flex d-lg-none p-4 bg-white h-100 collapsed" data-bs-target="#menu18" data-bs-toggle="collapse" type="button">
#            <span class="c-icon c-icon--toggle c-icon--sm c-icon--primary svgbox">
#             <svg viewbox="0 0 25.06 13.88" xmlns="http://www.w3.org/2000/svg">
#              <path d="M25.06,1.61c0,.38-.15,.77-.44,1.06L14,13.29c-.78,.78-2.05,.78-2.83,0L.44,2.56C-.15,1.97-.15,1.03,.44,.44,1.02-.15,1.98-.15,2.56,.44L12.59,10.46,22.42,.63c.57-.57,1.5-.68,2.11-.16,.35,.3,.53,.72,.53,1.15Z">
#              </path>
#             </svg>
#            </span>
#           </button>
#          </div>
#          <div class="c-header-aacoustic__submenu">
#           <div class="submenu-wrapper collapse w-100" data-bs-parent="#menu" id="menu18">
#            <div class="container">
#             <div class="row gx-0 gx-md-5">
#              <div class="col-12 col-lg-4 py-lg-0 py-5">
#               <div class="row h-100 flex-column flex-md-row-reverse flex-lg-row align-items-center align-items-md-stretch">
#                <div class="col-12 col-md-5 d-flex flex-column align-items-center">
#                 <span class="c-title fs-5 fw-bold text-primary text-center text-md-start d-md-none">
#                  Protections auditives
#                 </span>
#                 <img alt="Protections auditives" class="mw-100 my-4 my-md-0" src="/img/menu/audio_ear_protection.png"/>
#                </div>
#                <div class="col-12 col-md-7 d-flex flex-column align-items-md-start align-items-center">
#                 <span class="c-title fs-5 fw-bold text-primary d-md-block d-none">
#                  Protections auditives
#                 </span>
#                 <p class="fs-6 my-4 d-none d-md-block flex-grow-1">
#                  Profitez des concerts, festivals et autres évènements tout en protégeant votre audition grâce aux bouchons d’oreilles ALAIN AFFLELOU Acousticien.
#                 </p>
#                 <a class="c-btn c-btn--afflelou mt-1" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_see_catalog","label":"Protections auditives"}' data-role="datalayer-push-click" href="https://www.afflelou.com/audiologie/afflelou/protections-auditives-dediees-aux-concerts.html" target="_blank">
#                  VOIR LE CATALOGUE
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="col-12 col-lg-4 py-lg-0 py-5">
#               <div class="row h-100 flex-column flex-md-row-reverse flex-lg-row align-items-center align-items-md-stretch">
#                <div class="col-12 col-md-5 d-flex flex-column align-items-center">
#                 <span class="c-title fs-5 fw-bold text-primary text-center text-md-start d-md-none">
#                  Produits d'entretien et accessoires
#                 </span>
#                 <img alt="Ensemble de produits d'entretien" class="mw-100 my-4 my-md-0" src="/img/menu/audio_solutions.png"/>
#                </div>
#                <div class="col-12 col-md-7 d-flex flex-column align-items-md-start align-items-center">
#                 <span class="c-title fs-5 fw-bold text-primary d-md-block d-none">
#                  Produits d'entretien et accessoires
#                 </span>
#                 <p class="fs-6 my-4 d-none d-md-block flex-grow-1">
#                  Prenez soin de vos appareils auditifs grâce à nos produits d'entretiens : Sprays nettoyants, serviettes nettoyantes, capsules déshydratantes...
#                 </p>
#                 <a class="c-btn c-btn--afflelou mt-1" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_submenu&quot;,&quot;action&quot;:&quot;click_see_catalog&quot;,&quot;label&quot;:&quot;Produits d'entretien et accessoires&quot;}" data-role="datalayer-push-click" href="https://www.afflelou.com/audiologie/produits-entretien/" target="_blank">
#                  VOIR LE CATALOGUE
#                 </a>
#                </div>
#               </div>
#              </div>
#              <div class="col-12 col-lg-4 py-lg-0 py-5">
#               <div class="row h-100 flex-column flex-md-row-reverse flex-lg-row align-items-center align-items-md-stretch">
#                <div class="col-12 col-md-5 d-flex flex-column align-items-center">
#                 <span class="c-title fs-5 fw-bold text-primary text-center text-md-start d-md-none">
#                  Piles et connectivité
#                 </span>
#                 <img alt="Ensemble de piles" class="mw-100 my-4 my-md-0" src="/img/menu/audio_batteries.png"/>
#                </div>
#                <div class="col-12 col-md-7 d-flex flex-column align-items-md-start align-items-center">
#                 <span class="c-title fs-5 fw-bold text-primary d-md-block d-none">
#                  Piles et connectivité
#                 </span>
#                 <p class="fs-6 my-4 d-none d-md-block flex-grow-1">
#                  Grâce à nos piles universelles qui s'adaptent à tous les types d'appareils auditifs, vous pourrez toujours bien entendre au quotidien.
#                  <br/>
#                  <br/>
#                  Nous vous proposons des paquets de 6 piles ou des lots de 10, soit 60 piles, afin que vous ne soyez jamais à court.
#                 </p>
#                 <a class="c-btn c-btn--afflelou mt-1" data-elements='{"event":"GAevent","category":"header_submenu","action":"click_see_catalog","label":"Piles et connectivit\u00e9"}' data-role="datalayer-push-click" href="https://www.afflelou.com/audiologie/piles/" target="_blank">
#                  VOIR LE CATALOGUE
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="menu-item">
#          <div class="d-flex">
#           <a class="menu-link" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;header_menu&quot;,&quot;action&quot;:&quot;click_header&quot;,&quot;label&quot;:&quot;J'ai ou\u00ef dire&quot;}" data-role="datalayer-push-click" href="/conseils">
#            J'ai ouï dire
#            <span class="menu-link__arrow">
#            </span>
#           </a>
#          </div>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div id="js-content">
#    <section class="c-section border-top border-bottom border-gray-e py-4" data-component="headband">
#     <div class="container container--medium">
#      <h1 class="c-title fs-4 fw-bold text-center text-lightblack mx-auto" data-component="headband-title">
#       Audioprothésistes ALAIN AFFLELOU Acousticien France
#      </h1>
#     </div>
#    </section>
#    <section class="c-section bg-white py-5">
#     <div class="container container--medium">
#      <ul class="c-list c-list--dott c-list--columns ps-0">
#       <li class="c-list__element mt-0">
#        <a class="fs-6 text-black fw-bold" href="https://www.alainafflelou-acousticien.fr/audioprothesiste/ajaccio/afflelou-17-cours-jean-nicoli-20090">
#         Ajaccio
#        </a>
#       </li>
#       <li class="c-list__element mt-0">
#        <a class="fs-6 text-black fw-bold" href="https://www.alainafflelou-acousticien.fr/audioprothesiste/france/albi">
#         Albi
#        </a>
#        <span class="fs-6">
#         (2 boutiques)
#        </span>
#       </li>
#       <li class="c-list__element mt-0">
#        <a class="fs-6 text-black fw-bold" href="https://www.alainafflelou-acousticien.fr/audioprothesiste/alencon/afflelou-zac-les-portes-de-bretagne-61000">
#         Alençon
#        </a>
#       </li>
# ...
#         </div>
#         <div class="col-md-4 menu">
#          <div class="social-media">
#           <a class="c-title c-title--base-sm mb-2 d-inline-block text-white" href="#">
#            Suivez-nous
#           </a>
#           <a data-elements='{"event":"GAevent","category":"footer_menu","action":"Suivez-nous","label":"Facebook"}' data-role="datalayer-push-click" href="https://www.facebook.com/AlainAfflelouAcousticien/" target="_blank">
#            <img acousticien="" afflelou="" alt="Alain" facebook="" src="/img/social/facebook.svg" sur=""/>
#           </a>
#           <a data-elements='{"event":"GAevent","category":"footer_menu","action":"Suivez-nous","label":"LinkedIn"}' data-role="datalayer-push-click" href="https://www.linkedin.com/company/alain-afflelou-acousticien/" target="_blank">
#            <img alt="Alain Afflelou Acousticien sur Linkedin" src="/img/social/linkedin.svg"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="col menu-other">
#        <div class="row">
#         <div class="col-lg-12 col-md-4">
#          <span class="c-title c-title--base-sm mb-2 d-inline-block text-white">
#           Autres enseignes
#          </span>
#          <ul>
#           <li class="footer-menu-item">
#            <a class="footer-menu-link" data-elements='{"event":"GAevent","category":"footer_menu","action":"others","label":"ALAIN AFFLELOU OPTICIEN"}' data-role="datalayer-push-click" href="https://www.afflelou.com/" target="_blank">
#             ALAIN AFFLELOU OPTICIEN
#            </a>
#           </li>
#           <li class="footer-menu-item">
#            <a class="footer-menu-link" data-elements='{"event":"GAevent","category":"footer_menu","action":"others","label":"Malentille"}' data-role="datalayer-push-click" href="https://www.malentille.com/" target="_blank">
#             Malentille
#            </a>
#           </li>
#           <li class="footer-menu-item">
#            <a class="footer-menu-link" data-elements='{"event":"GAevent","category":"footer_menu","action":"others","label":"Optical Discount"}' data-role="datalayer-push-click" href="https://www.opticaldiscount.com/" target="_blank">
#             Optical Discount
#            </a>
#           </li>
#          </ul>
#          <ul class="mt-5">
#           <li class="footer-menu-item">
#            <a class="footer-menu-link" data-elements='{"event":"GAevent","category":"footer_menu","action":"others","label":"Qui sommes-nous ?"}' data-role="datalayer-push-click" href="https://www.afflelou.com/entreprise/" target="_blank">
#             Qui sommes-nous ?
#            </a>
#           </li>
#           <li class="footer-menu-item">
#            <a class="footer-menu-link" data-elements='{"event":"GAevent","category":"footer_menu","action":"others","label":"Espace presse"}' data-role="datalayer-push-click" href="https://www.afflelou.com/presse" target="_blank">
#             Espace presse
#            </a>
#           </li>
#           <li class="footer-menu-item">
#            <a class="footer-menu-link" data-elements="{&quot;event&quot;:&quot;GAevent&quot;,&quot;category&quot;:&quot;footer_menu&quot;,&quot;action&quot;:&quot;others&quot;,&quot;label&quot;:&quot;Voir nos offres d'emploi&quot;}" data-role="datalayer-push-click" href="https://www.afflelou.com/nous-rejoindre/offres" target="_blank">
#             Voir nos offres d'emploi
#            </a>
#           </li>
#          </ul>
#          <a class="btn" data-elements='{"event":"GAevent","category":"footer_menu","action":"others","label":"Ouvrir une franchise Alain Afflelou Acousticien"}' data-role="datalayer-push-click" href="/ouvrir-franchise-audioprothesiste">
#           Ouvrir une franchise Alain Afflelou Acousticien
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="c-footer-aacoustic__bottom text-white">
#     <div class="container container--short">
#      <ul class="d-flex align-items-center justify-content-center flex-wrap">
#       <li class="bottom-link">
#        © Copyright ALAIN AFFLELOU 2023
#       </li>
#       <li>
#        <a class="bottom-link" data-elements='{"event":"GAevent","category":"footer_legals","action":"Politique de protection des donn\u00e9es personnelles"}' data-role="datalayer-push-click" href="/politique-donnees-personnelles">
#         Politique de protection des données personnelles
#        </a>
#       </li>
#       <li>
#        <a class="bottom-link" data-elements='{"event":"GAevent","category":"footer_legals","action":"Mentions l\u00e9gales"}' data-role="datalayer-push-click" href="/mentions-legales">
#         Mentions légales
#        </a>
#       </li>
#       <li>
#        <a class="bottom-link" data-elements='{"event":"GAevent","category":"footer_legals","action":"CGU"}' data-role="datalayer-push-click" href="/conditions-generales-utilisation">
#         CGU
#        </a>
#       </li>
#       <li>
#        <a class="bottom-link" data-elements='{"event":"GAevent","category":"footer_legals","action":"Cookies"}' data-role="datalayer-push-click" href="/cookies">
#         Cookies
#        </a>
#       </li>
#       <li>
#        <a class="bottom-link" data-elements='{"event":"GAevent","category":"footer_legals","action":"Mesures sanitaires"}' data-role="datalayer-push-click" href="/mesures-sanitaires-et-entretien">
#         Mesures sanitaires
#        </a>
#       </li>
#       <li>
#        <a class="bottom-link" data-elements='{"event":"GAevent","category":"footer_legals","action":"FAQ"}' data-role="datalayer-push-click" href="/faq">
#         FAQ
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </footer>
#   <button class="c-btn c-btn--md c-btn--primary c-btn--callback c-icon--before c-icon--lg js-callback-open" data-bs-target="#formCallback" data-bs-toggle="modal" data-elements='{"event":"GAevent","category":"form_call_back","action":"click_CTA"}' data-role="datalayer-push-click" type="button">
#    <span class="svgbox">
#     <svg viewbox="0 0 30 30" xmlns="http://www.w3.org/2000/svg">
#      <path d="M22.24,18.17a10.48,10.48,0,0,1-3.21-.5.84.84,0,0,0-.91.23l-2,2a13.64,13.64,0,0,1-6-6l2-2a.84.84,0,0,0,.23-.9,9.66,9.66,0,0,1-.55-3.26.9.9,0,0,0-.9-.9H7.76a.9.9,0,0,0-.9.9A15.36,15.36,0,0,0,22.24,23.14a.9.9,0,0,0,.9-.9V19.07A.9.9,0,0,0,22.24,18.17Z">
#      </path>
#      <path d="M15,30A15,15,0,1,1,30,15,15,15,0,0,1,15,30ZM15,2A13,13,0,1,0,28,15,13,13,0,0,0,15,2Z">
#      </path>
#     </svg>
#    </span>
#    <span class="fs-5 fw-bold">
#     ÊTRE RAPPELÉ
#    </span>
#   </button>
#   <div aria-hidden="true" aria-labelledby="formCallbackLabel" class="modal modal--callback fade" id="formCallback" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content justify-content-center px-5 px-sm-6 py-7">
#      <button class="modal-close c-btn c-btn--close c-btn--callback-close c-icon c-icon--sm position-absolute m-0 m-s-4" data-bs-target="#formCallback" data-bs-toggle="modal" type="button">
#       <span class="svgbox">
#        <svg viewbox="0 0 12.24 12.24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M961.13,540.37l4.41-4.41a1,1,0,1,0-1.41-1.41L959.71,539l-4.41-4.41a1,1,0,0,0-1.41,1.41l4.41,4.41-4.41,4.42a1,1,0,0,0,0,1.41,1,1,0,0,0,1.41,0l4.41-4.41,4.42,4.41a1,1,0,0,0,.7.29,1,1,0,0,0,.71-.29,1,1,0,0,0,0-1.41Z" transform="translate(-953.6 -534.25)">
#         </path>
#        </svg>
#       </span>
#      </button>
#      <h2 class="c-title c-title--primary fs-4 fw-normal text-start">
#       ÊTRE RAPPELÉ POUR
#       <br/>
#       <span class="fw-bolder">
#        PRENDRE RENDEZ-VOUS
#       </span>
#      </h2>
#      <span class="text-lightblack fs-5">
#       Complétez le formulaire ci-dessous et nos conseillers vous rappellerons dans les plus brefs délais du lundi au vendredi de 9h à 17h.
#      </span>
#      <div data-component="form-tmk" id="form-tmk">
#       <form action="/form/tmk/contact" class="c-form" id="form_call_back" method="post" name="form_tmk_contact" novalidate="novalidate">
#        <div class="row gx-4 mt-4">
#         <fieldset class="c-form-fieldset col-12">
#          <span class="c-form-group__label">
#           Civilité
#           <sup>
#            *
#           </sup>
#          </span>
#          <div class="c-form-group c-form-group--radio c-form-group--inline">
#           <input class="c-form__field" id="form_tmk_contact_title_0" name="form_tmk_contact[title]" required="required" type="radio" value="M"/>
#           <label class="c-form__label" for="form_tmk_contact_title_0">
#            Madame
#           </label>
#          </div>
#          <div class="c-form-group c-form-group--radio c-form-group--inline">
#           <input class="c-form__field" id="form_tmk_contact_title_1" name="form_tmk_contact[title]" required="required" type="radio" value="H"/>
#           <label class="c-form__label" for="form_tmk_contact_title_1">
#            Monsieur
#           </label>
#          </div>
#         </fieldset>
#         <div class="c-form-group col-12">
#          <input class="c-form__field" id="form_tmk_contact_lastName" name="form_tmk_contact[lastName]" placeholder="Nom*" required="required" type="text"/>
#         </div>
#         <div class="c-form-group col-12">
#          <input class="c-form__field" id="form_tmk_contact_firstName" name="form_tmk_contact[firstName]" placeholder="Prénom*" required="required" type="text"/>
#         </div>
#         <div class="c-form-group col-12 col-md-6">
#          <select class="c-form__field c-form__field--select" id="form_tmk_contact_phone_country" name="form_tmk_contact[phone][country]">
#           <option value="FR">
#            France (+33)
#           </option>
#           <option disabled="disabled">
#            -------------------
#           </option>
#           <option value="FR">
#            France (+33)
#           </option>
#           <option value="GP">
#            Guadeloupe (+590)
#           </option>
#           <option value="GF">
#            Guyane française (+594)
#           </option>
#           <option value="RE">
#            La Réunion (+262)
#           </option>
#           <option value="MQ">
#            Martinique (+596)
#           </option>
#           <option value="MU">
#            Maurice (+230)
#           </option>
#           <option value="YT">
#            Mayotte (+262)
#           </option>
#           <option value="NC">
#            Nouvelle-Calédonie (+687)
#           </option>
#           <option value="PF">
#            Polynésie française (+689)
#           </option>
#          </select>
#         </div>
#         <div class="c-form-group col-12 col-md-6">
#          <input class="c-form__field" id="form_tmk_contact_phone_number" name="form_tmk_contact[phone][number]" placeholder="Téléphone*" required="required" type="text"/>
#         </div>
#         <div class="c-form-group col-12">
#          <input class="c-form__field" id="form_tmk_contact_email" name="form_tmk_contact[email]" placeholder="Adresse e-mail*" type="email"/>
#         </div>
#         <div class="c-form-group c-form-group--checkbox c-form-group--inline col-12">
#          <input class="c-form__field" id="form-callback-commercials" name="form_tmk_contact[newsletter]" type="checkbox" value="1"/>
#          <label class="c-form__label fs-6 text-lightblack" for="form_tmk_contact_newsletter">
#           J'accepte de recevoir les offres et actualités envoyées par les marques du Groupe Afflelou (Opticien et Acousticien).
#          </label>
#         </div>
#         <input data-component="query-params" data-method="getFromStorageToInputValue" data-param="codemedia" id="form_tmk_contact_mediaCode" name="form_tmk_contact[mediaCode]" type="hidden" value="ACFLEA"/>
#         <span class="fs-6 text-primary pt-3">
#          * Champs obligatoires
#         </span>
#         <div class="col-12 mt-3">
#          <div class="c-btn--loading bg-transparent is-loading position-relative d-none" data-component="loading-animation">
#           <span class="c-icon c-icon--primary c-icon--loading svgbox">
#            <svg version="1.1" viewbox="0 0 50 50" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#             <circle cx="25" cy="25" fill="none" r="20" stroke-width="5">
#             </circle>
#            </svg>
#           </span>
#          </div>
#          <button class="c-btn c-btn--primary fw-bolder w-100" data-component="loading-button" id="form_callback_submit" type="submit">
#           ÊTRE RAPPELÉ
#          </button>
#         </div>
#        </div>
#        <input id="form_tmk_contact_type" name="form_tmk_contact[type]" type="hidden" value="contact"/>
#        <input id="form_tmk_contact_origin_route" name="form_tmk_contact[origin_route]" type="hidden" value="shop_locator_by_country"/>
#        <input data-component="query-params" data-method="getFromStorageToInputValue" data-param="gclid" id="form_tmk_contact_gclid" name="form_tmk_contact[gclid]" type="hidden"/>
#        <input id="form_tmk_contact_utm_channel" name="form_tmk_contact[utm_channel]" type="hidden"/>
#        <input id="form_tmk_contact_utm_term" name="form_tmk_contact[utm_term]" type="hidden"/>
#        <input id="form_tmk_contact_utm_campaign" name="form_tmk_contact[utm_campaign]" type="hidden"/>
#        <input id="form_tmk_contact_utm_content" name="form_tmk_contact[utm_content]" type="hidden"/>
#        <input id="form_tmk_contact_utm_source" name="form_tmk_contact[utm_source]" type="hidden"/>
#        <input id="form_tmk_contact_utm_medium" name="form_tmk_contact[utm_medium]" type="hidden"/>
#        <input id="form_tmk_contact__token" name="form_tmk_contact[_token]" type="hidden" value="ac631.hIAYoydRhaDHr8iyYy5qeYRS6W49cm0JxokY9FxJfmw.4fJ1wUp81OmU14zxW09TPMEXmA9zMzdq9OB7kgklJALdyFHybyLhx_Louw"/>
#       </form>
#      </div>
#      <div class="row u-index-0">
#       <span class="fs-5 text-lightblack text-center c-separator c-separator--line-full">
#        Vous pouvez également prendre
#        <br/>
#        rendez-vous ici :
#       </span>
#       <div class="col-12 mt-4">
#        <a class="c-btn c-btn--outline-primary c-icon--before" data-elements='{"event":"GAevent","category":"form_call_back","action":"click_appointment","label":"https:\/\/www.alainafflelou-acousticien.fr\/audioprothesiste\/france"}' data-role="datalayer-push-click" href="/rendez-vous/trouver-centre-acousticien">
#         <span class="svgbox">
#          <svg viewbox="0 0 16.5 17.88" xmlns="http://www.w3.org/2000/svg">
#           <path d="M19.3,4.94a1.84,1.84,0,0,0-1.69-1.09h-.92V2.06H14.86V3.85H7.53V2.06H5.69V3.85H4.78a1.83,1.83,0,0,0-1.52.79,1.73,1.73,0,0,0-.32,1V18.15a1.82,1.82,0,0,0,1.84,1.79H17.61a1.81,1.81,0,0,0,1.83-1.79V5.64A1.82,1.82,0,0,0,19.3,4.94Zm-.86,13.21a.82.82,0,0,1-.83.79H4.78a.82.82,0,0,1-.84-.79V8.22h14.5Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M7.53,10.89a.92.92,0,1,0-.92.9A.91.91,0,0,0,7.53,10.89Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M5.69,16.26a.92.92,0,1,0,.92-.9A.91.91,0,0,0,5.69,16.26Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M5.69,13.57a.92.92,0,1,0,.92-.89A.91.91,0,0,0,5.69,13.57Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M10.28,16.26a.92.92,0,1,0,.91-.9A.9.9,0,0,0,10.28,16.26Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M10.28,13.57a.92.92,0,1,0,.91-.89A.9.9,0,0,0,10.28,13.57Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M10.28,10.89a.92.92,0,1,0,.91-.89A.9.9,0,0,0,10.28,10.89Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M14.86,16.26a.92.92,0,1,0,.92-.9A.91.91,0,0,0,14.86,16.26Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M15.78,12.68a.9.9,0,1,0,.91.89A.91.91,0,0,0,15.78,12.68Z" transform="translate(-2.94 -2.06)">
#           </path>
#           <path d="M14.86,10.89a.92.92,0,1,0,.92-.89A.91.91,0,0,0,14.86,10.89Z" transform="translate(-2.94 -2.06)">
#           </path>
#          </svg>
#         </span>
#         Prendre rendez-vous
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script src="/runtime.7fc6ffa1.js">
#   </script>
#   <script src="/277.e2d967b7.js">
#   </script>
#   <script src="/app.6ee0af3d.js">
#   </script>
#  </body>
# </html>

# %%
links = []
flags = []

shops = soup.find_all('li', {'class':'c-list__element mt-0'})
for shop in shops:
    links.append(shop.a.get('href'))
    try:
        flg = shop.span.contents[0] is not None
    except AttributeError:
        flg = False
    flags.append(flg)

# %%
def find_address(link, flag):
    if flag:
        page = urllib3.PoolManager().request('GET', link)
        soup = BeautifulSoup(page.data, features="html.parser")
        city = link.split('/')[-1]

        tags = soup.find_all('div', {'class':'d-flex flex-column fw-bold'})
        address = [t.contents[0].strip('\n').strip(' ').strip('\n')+f' {city.upper()} FR' for t in tags]

    if not flag:
        page = urllib3.PoolManager().request('GET', link)
        soup = BeautifulSoup(page.data, features="html.parser")

        tags = soup.find_all('span')
        mask = [elem.get('itemprop') for elem in tags]
        address_components = [elem.contents[0].strip('\n').strip() for elem in compress(tags, mask)]
        address = [' '.join(address_components)]
    
    return(address)

# %%
# 8 min ca
address_list = []

for i, (l, f) in enumerate(zip(links, flags)):
   if((i>0) and (i%20==0)):
      print(f'Scraping link {i}/{len(links)}....')
   address_list.extend(find_address(l, f))

df = pd.DataFrame({'address': address_list})
df.head()
# Out:
# Scraping link 20/322....
# Scraping link 40/322....
# Scraping link 60/322....
# Scraping link 80/322....
# Scraping link 100/322....
# Scraping link 120/322....
# Scraping link 140/322....
# Scraping link 160/322....
# Scraping link 180/322....
# Scraping link 200/322....
# Scraping link 220/322....
# Scraping link 240/322....
# Scraping link 260/322....
# Scraping link 280/322....
# Scraping link 300/322....
# Scraping link 320/322....
#                                              address
# 0              17 cours Jean Nicoli 20090 AJACCIO FR
# 1     C.C. E.Leclerc - rue des Portes d'Albi ALBI FR
# 2                   97 Avenue de Saint-Juéry ALBI FR
# 3        ZAC Les Portes de Bretagne 61000 ALENÇON FR
# 4  16 Place des Martyrs de la Résistance 30100 AL...

# %%
# geolocate shops
geolocator = IGNFrance()

df['latitude'] = np.nan
df['longitude'] = np.nan
df['city'] = np.nan
df['postcode'] = np.nan

for i in df.index:

    if ((i>0) and (i%50==0)):
        print(f'{i}/{len(df)}')

    try:
        #tries fetch address from geopy
        location = geolocator.geocode(df['address'][i], timeout=None)
        
        #append lat/long to column using dataframe location
        df.loc[i,'latitude'] = float(location.latitude)
        df.loc[i,'longitude'] = float(location.longitude)
        df.loc[i,'city'] = location.raw['commune']
        df.loc[i,'postcode'] = location.raw['postal_code']
        
    except:
        continue
# Out:
# 50/355
# 100/355
# 150/355
# 200/355
# 250/355
# 300/355
# 350/355

# %%
# check
df.head()
# Out:
#                                              address   latitude  longitude  \
# 0              17 cours Jean Nicoli 20090 AJACCIO FR  42.462065   1.937261
# 1     C.C. E.Leclerc - rue des Portes d'Albi ALBI FR  43.923305   2.149627
# 2                   97 Avenue de Saint-Juéry ALBI FR  43.935898   2.179227
# 3        ZAC Les Portes de Bretagne 61000 ALENÇON FR  48.432597   0.069882
# 4  16 Place des Martyrs de la Résistance 30100 AL...  44.126526   4.079116
#
#       city postcode
# 0       Ur    66760
# 1     Albi    81000
# 2     Albi    81000
# 3  Alençon    61000
# 4     Alès    30100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355 entries, 0 to 354
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   address    355 non-null    object
#  1   latitude   355 non-null    float64
#  2   longitude  355 non-null    float64
#  3   city       355 non-null    object
#  4   postcode   355 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 14.0+ KB

# %%
df.to_csv('../output/affleolu_shops_geocoded.csv', index=False)
